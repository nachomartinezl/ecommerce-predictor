# %%
import pandas as pd
import numpy as np
import time
from xgboost import XGBClassifier
from model.text_normalizer import normalize_corpus, stopword_list
from model import evaluation
from model.utils import decoder
from scripts.build_df import build_df
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from scripts import tree_utils
from sklearn.base import BaseEstimator, TransformerMixin
from joblib import dump, load
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = build_df(json_path='data/products.json', 
             threshold=100, 
             preprocessed_csv=None
            )

# %%
df[['name', 'description','category', 'image']].to_csv('data/products_v1.csv',index=False)

# %%
df = pd.read_csv('data/products_v1.csv')

def normalization(input):
    output = normalize_corpus(
        input,
        html_stripping=True,
        contraction_expansion=True,
        accented_char_removal=True,
        text_lower_case=True,
        text_stemming=True,
        text_lemmatization=False,
        special_char_removal=True,
        remove_digits=False,
        stopword_removal=True,
        stopwords=stopword_list
    )       
    return output

df['name'] = normalization(df['name'].apply(str))
df['description'] = normalization(df['description'].apply(str))
df['name_and_description'] = [' '.join(i) for i in zip(df['name'], df['description'])]

normalized_data = df.to_csv('data/normalized_data.csv', index=False)

# %%
name = df['name'].apply(str)
description = df['description'].apply(str)
name_and_description = df['name_and_description'].apply(str)
X = name_and_description

# %%
cat = build_df(json_path='data/products.json', 
             threshold=100, 
             preprocessed_csv='data/normalized_data.csv'
            )

# %%
y = cat.iloc[:,6:].fillna('Unknown')

# %%
y
# Out:
#                category_0          category_1          category_2  \
# 0      pcmcat312300050015  pcmcat248700050021  pcmcat303600050001
# 1      pcmcat312300050015  pcmcat248700050021  pcmcat303600050001
# 2      pcmcat312300050015  pcmcat248700050021  pcmcat303600050001
# 3      pcmcat312300050015  pcmcat248700050021  pcmcat303600050001
# 4      pcmcat312300050015  pcmcat248700050021  pcmcat303600050001
# ...                   ...                 ...                 ...
# 51641        abcat0900000        abcat0916000  pcmcat303700050016
# 51642        abcat0900000        abcat0916000        abcat0916008
# 51643        abcat0500000        abcat0515000        abcat0504001
# 51644        abcat0100000             Unknown             Unknown
# 51645        abcat0900000        abcat0912000        abcat0912023
#
#                category_3 category_4 category_5 category_6
# 0                 Unknown    Unknown    Unknown    Unknown
# 1                 Unknown    Unknown    Unknown    Unknown
# 2                 Unknown    Unknown    Unknown    Unknown
# 3                 Unknown    Unknown    Unknown    Unknown
# 4                 Unknown    Unknown    Unknown    Unknown
# ...                   ...        ...        ...        ...
# 51641             Unknown    Unknown    Unknown    Unknown
# 51642             Unknown    Unknown    Unknown    Unknown
# 51643  pcmcat186100050005    Unknown    Unknown    Unknown
# 51644             Unknown    Unknown    Unknown    Unknown
# 51645             Unknown    Unknown    Unknown    Unknown
#
# [51646 rows x 7 columns]

# %%
tree_dict = tree_utils.make_tree(cat, cat['category'], 'Categories', display_tree= True)
# Out:
# Categories
# ├── pcmcat312300050015
# │   ├── pcmcat248700050021
# │   │   ├── pcmcat303600050001
# │   │   └── pcmcat179100050006
# │   │       ├── pcmcat179200050003
# │   │       ├── pcmcat179200050008
# │   │       │   └── pcmcat748300322875
# │   │       └── pcmcat179200050013
# │   ├── abcat0802000
# │   │   ├── abcat0811011
# │   │   └── abcat0802001
# │   │       └── pcmcat159300050002
# │   ├── abcat0805000
# │   │   └── abcat0511001
# │   │       └── pcmcat266500050030
# │   ├── pcmcat275600050000
# │   │   └── abcat0807000
# │   │       ├── abcat0807001
# │   │       ├── pcmcat335400050008
# │   │       └── abcat0807009
# │   ├── abcat0809000
# │   │   ├── abcat0809004
# │   │   └── abcat0809002
# │   ├── pcmcat249700050006
# │   │   ├── pcmcat219100050010
# │   │   ├── pcmcat286300050020
# │   │   └── pcmcat272800050000
# │   ├── pcmcat254000050002
# │   │   └── pcmcat308100050020
# │   │       └── pcmcat340500050007
# │   └── pcmcat341100050005
# │       └── pcmcat253700050018
# │           └── pcmcat248300050003
# ├── other
# ├── abcat0300000
# │   ├── pcmcat165900050023
# │   │   └── pcmcat331600050007
# │   │       └── pcmcat165900050031
# │   │           ├── pcmcat165900050033
# │   │           ├── pcmcat165900050034
# │   │           └── pcmcat165900050032
# │   ├── abcat0302000
# │   │   ├── abcat0302034
# │   │   │   └── abcat0302037
# │   │   ├── abcat0302001
# │   │   ├── abcat0302012
# │   │   └── abcat0302005
# │   ├── pcmcat156300050006
# │   └── abcat0301000
# ├── abcat0207000
# │   ├── pcmcat152100050020
# │   ├── abcat0208024
# │   │   └── pcmcat151600050008
# │   ├── pcmcat152100050035
# │   │   └── pcmcat251600050003
# │   │       └── pcmcat152100050038
# │   ├── pcmcat151600050037
# │   ├── pcmcat152100050027
# │   ├── pcmcat152200050014
# │   │   ├── pcmcat202800050013
# │   │   └── pcmcat251500050009
# │   ├── pcmcat152100050010
# │   └── pcmcat151600050019
# │       └── pcmcat221400050011
# │           └── pcmcat151600050027
# ├── pcmcat252700050006
# │   ├── pcmcat244200050008
# │   ├── pcmcat284400050091
# │   └── pcmcat369900050001
# ├── abcat0700000
# │   ├── abcat0706000
# │   ├── abcat0701000
# │   │   └── abcat0701002
# │   ├── pcmcat232900050017
# │   ├── abcat0707000
# │   │   └── abcat0707002
# │   ├── abcat0703000
# │   │   └── abcat0703002
# │   ├── abcat0712000
# │   ├── pcmcat232900050000
# │   ├── abcat0715000
# │   ├── pcmcat295700050012
# │   │   └── pcmcat296300050018
# │   ├── pcmcat300300050002
# │   │   └── pcmcat303600050005
# │   └── pcmcat306400050032
# ├── abcat0400000
# │   ├── abcat0401000
# │   │   └── abcat0401001
# │   │       └── pcmcat324200050004
# │   ├── abcat0410022
# │   │   └── pcmcat329700050009
# │   │       └── pcmcat240500050057
# │   ├── abcat0410000
# │   │   ├── abcat0410018
# │   │   │   ├── pcmcat233000050008
# │   │   │   │   └── pcmcat195200050001
# │   │   │   └── pcmcat374500050006
# │   │   ├── abcat0410020
# │   │   ├── abcat0410012
# │   │   │   └── pcmcat284800050007
# │   │   ├── pcmcat284800050006
# │   │   │   └── abcat0410001
# │   │   │       └── pcmcat328900050008
# │   │   ├── abcat0410045
# │   │   └── pcmcat240500050025
# │   │       └── pcmcat240500050052
# │   ├── abcat0404000
# │   │   └── pcmcat225800050009
# │   └── abcat0409000
# │       └── abcat0409001
# ├── abcat0500000
# │   ├── abcat0515000
# │   │   ├── abcat0515042
# │   │   ├── pcmcat221100050003
# │   │   ├── abcat0515025
# │   │   │   ├── pcmcat183800050007
# │   │   │   ├── pcmcat183800050006
# │   │   │   └── abcat0515028
# │   │   ├── abcat0513000
# │   │   │   ├── pcmcat338200050008
# │   │   │   └── abcat0513004
# │   │   ├── abcat0504001
# │   │   │   └── pcmcat186100050005
# │   │   ├── abcat0504010
# │   │   └── abcat0515012
# │   │       └── abcat0515013
# │   ├── abcat0507000
# │   ├── pcmcat309900050001
# │   │   └── pcmcat242000050002
# │   │       └── pcmcat344400050007
# │   ├── abcat0509000
# │   │   └── pcmcat200900050014
# │   ├── abcat0508000
# │   ├── pcmcat209000050006
# │   │   └── pcmcat209000050008
# │   ├── abcat0503000
# │   ├── abcat0502000
# │   │   └── pcmcat138500050001
# │   │       └── pcmcat247400050000
# │   └── abcat0501000
# │       └── pcmcat143400050013
# ├── abcat0900000
# │   ├── abcat0904000
# │   │   ├── abcat0904001
# │   │   ├── abcat0904004
# │   │   │   └── pcmcat180700050008
# │   │   ├── abcat0904003
# │   │   │   ├── pcmcat196400050015
# │   │   │   └── pcmcat196400050016
# │   │   └── abcat0904002
# │   │       └── pcmcat207200050007
# │   ├── abcat0912000
# │   │   ├── pcmcat367400050002
# │   │   │   ├── pcmcat367400050005
# │   │   │   │   └── abcat0912008
# │   │   │   ├── abcat0912005
# │   │   │   │   └── pcmcat258900050007
# │   │   │   └── pcmcat367400050003
# │   │   │       └── pcmcat194000050023
# │   │   ├── abcat0912011
# │   │   │   └── pcmcat194000050018
# │   │   │       └── pcmcat258900050003
# │   │   ├── abcat0912014
# │   │   ├── abcat0912025
# │   │   │   └── pcmcat251300050004
# │   │   ├── abcat0912023
# │   │   ├── abcat0912012
# │   │   ├── abcat0912020
# │   │   ├── pcmcat748301695371
# │   │   │   ├── pcmcat226900050013
# │   │   │   └── pcmcat748301695443
# │   │   ├── abcat0912018
# │   │   └── pcmcat194000050022
# │   ├── abcat0902000
# │   ├── pcmcat302300050021
# │   │   ├── abcat0907001
# │   │   ├── abcat0907007
# │   │   ├── abcat0908003
# │   │   ├── abcat0908001
# │   │   ├── pcmcat268100050002
# │   │   └── abcat0907006
# │   ├── abcat0901000
# │   │   └── pcmcat367400050001
# │   ├── abcat0903000
# │   │   └── pcmcat748301803023
# │   ├── abcat0910000
# │   │   ├── abcat0910004
# │   │   │   ├── pcmcat232900050031
# │   │   │   └── pcmcat232900050030
# │   │   └── abcat0910001
# │   ├── abcat0911000
# │   ├── abcat0905000
# │   │   └── abcat0905001
# │   └── abcat0916000
# │       ├── pcmcat303700050016
# │       └── abcat0916008
# ├── abcat0200000
# │   ├── abcat0204000
# │   │   ├── pcmcat144700050004
# │   │   ├── pcmcat143000050011
# │   │   │   ├── pcmcat331200050001
# │   │   │   └── pcmcat331200050000
# │   │   └── pcmcat143000050007
# │   ├── pcmcat241600050001
# │   │   ├── pcmcat309300050002
# │   │   ├── abcat0205000
# │   │   │   ├── abcat0205006
# │   │   │   ├── pcmcat210900050000
# │   │   │   │   └── pcmcat210900050001
# │   │   │   └── abcat0205001
# │   │   ├── abcat0203000
# │   │   │   └── abcat0205007
# │   │   └── pcmcat309300050003
# │   ├── abcat0208007
# │   ├── pcmcat310200050004
# │   └── abcat0208000
# │       └── abcat0208015
# ├── abcat0100000
# │   ├── abcat0106000
# │   │   ├── pcmcat332100050008
# │   │   │   └── pcmcat158900050019
# │   │   ├── abcat0106004
# │   │   ├── abcat0106001
# │   │   │   └── pcmcat332100050000
# │   │   └── abcat0106010
# │   ├── abcat0107000
# │   │   └── abcat0107015
# │   ├── abcat0101000
# │   │   └── abcat0101001
# │   └── pcmcat158900050008
# │       └── pcmcat158900050018
# ├── pcmcat242800050021
# │   ├── abcat0915000
# │   │   ├── abcat0915009
# │   │   └── abcat0915005
# │   ├── pcmcat352500050007
# │   ├── abcat0301006
# │   └── pcmcat210000050008
# ├── pcmcat128500050004
# ├── abcat0800000
# │   ├── abcat0811002
# │   │   ├── abcat0811006
# │   │   ├── pcmcat191200050015
# │   │   │   └── pcmcat214700050000
# │   │   │       ├── pcmcat748300579994
# │   │   │       └── pcmcat748300580023
# │   │   ├── abcat0811004
# │   │   │   ├── pcmcat326000050010
# │   │   │   └── pcmcat326000050011
# │   │   ├── pcmcat373300050003
# │   │   ├── abcat0811007
# │   │   │   ├── pcmcat171900050026
# │   │   │   └── pcmcat171900050024
# │   │   ├── pcmcat171900050031
# │   │   └── pcmcat321000050003
# │   │       └── pcmcat321000050005
# │   │           └── pcmcat350800050010
# │   ├── pcmcat156400050037
# │   │   └── pcmcat311200050005
# │   └── pcmcat209400050001
# ├── cat09000
# ├── pcmcat139900050002
# │   └── pcmcat748300660981
# │       └── pcmcat143200050025
# └── pcmcat332000050000
#     └── pcmcat748300489081
#         └── pcmcat377500050002
#             └── pcmcat377500050003

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20, 
    random_state=42,
    stratify = y
)

# %%
tfid_vectorizer = TfidfVectorizer(max_features=None, 
                                  ngram_range=(1, 2),
                                  use_idf=False,
                                  min_df=0.1,
                                  norm='l2',
                                  smooth_idf=True
                                 ) 
X_train = tfid_vectorizer.fit_transform(X_train)
X_test = tfid_vectorizer.transform(X_test)

# %%
logreg = LogisticRegression(max_iter=2000, 
                            n_jobs=-1, 
                            multi_class='multinomial', 
                            solver='newton-cg')

# %%
xgb = XGBClassifier(colsample_bytree= 0.7,
                    gamma = 0.25, 
                    learning_rate = 0.2,
                    max_depth = 5,
                    min_child_weight = 1,
                    reg_lambda=3,
                    scale_pos_weight=0.5,
                    subsample= 0.7,
                    booster='gbtree',
                    verbosity= 1,
                    n_jobs=-1)

# %%
clf = OneVsRestClassifier(XGBClassifier(colsample_bytree= 0.7,
                    gamma = 0.25, 
                    learning_rate = 0.2,
                    max_depth = 5,
                    min_child_weight = 1,
                    reg_lambda=3,
                    scale_pos_weight=0.5,
                    subsample= 0.7,
                    booster='gbtree',
                    verbosity= 1,
                    n_jobs=-1), n_jobs=-1)

params = {'xgb__colsample_bytree': [0.7],
                    'xgb__gamma': [0.25, 0.5, 1], 
                    'xgb__learning_rate': [0.2],
                    'xgb__max_depth': [3, 5],
                    'xgb__min_child_weight': [1, 5],
                    'xgb__reg_lambda': [0, 1, 3],
                    'xgb__scale_pos_weight': [0.5],
                    'xgb__subsample': [0.7],
                    'xgb__booster': ['gbtree'],
                    'xgb__verbosity': [2],
                    'xgb__num_parallel_tree': [4],
                    'xgb__n_jobs' : [-1]
                    }

# %%
rand = RandomizedSearchCV(clf, params, n_jobs=-1, cv=3, scoring="accuracy")

# %%
y_train = mlb.fit_transform(y_train.values.tolist())

# %%
y_test = mlb.transform(y_test.values.tolist())

# %%
clf.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=XGBClassifier(base_score=None, booster='gbtree',
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.7,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0.25,
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.2, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=5,
#                                             max_leaves=None, min_child_weight=1,
#                                             missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...),
#                     n_jobs=-1)

# %%
clf.score(X_train, y_train)
# Out:
# 0.08355116661825927

# %%
y_pred_test = clf.predict(X_test)
y_pred_train = clf.predict(X_train)

# %%
probs_test = clf.predict_proba(X_test)
probs_train = clf.predict_proba(X_train)

# %%
evaluation.get_performance(model=clf,
                           pred_labels=mlb.inverse_transform(y_pred_test), 
                           true_labels=mlb.inverse_transform(y_test),
                           probs=probs_test,
                           vectorizer=tfid_vectorizer,
                           average='micro',
                           tree= tree_dict)
# Out:
# /home/app/src/model/evaluation.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   true_labels = np.array(true_labels)
# /home/app/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:2360: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = [asarray(arg) for arg in args]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 evaluation.get_performance(model=clf,
#       2                            pred_labels=mlb.inverse_transform(y_pred_test),
#       3                            true_labels=mlb.inverse_transform(y_test),
#       4                            probs=probs_test,
#       5                            vectorizer=tfid_vectorizer,
#       6                            average='micro',
#       7                            tree= tree_dict)
#
# File ~/src/model/evaluation.py:29, in get_performance(model, pred_labels, true_labels, probs, average, tree, vectorizer)
#      26 y_true = decoder(true_labels) #antes y_test
#      27 y_pred = decoder(pred_labels) # antes predictions
# ---> 29 accuracy = metrics.accuracy_score(y_true, y_pred)
#      30 precision = metrics.precision_score(y_true, y_pred, average=average)
#      31 recall = metrics.recall_score(y_true, y_pred, average=average)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:104, in _check_targets(y_true, y_pred)
#     102 # No metrics support "multiclass-multioutput" format
#     103 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 104     raise ValueError("{0} is not supported".format(y_type))
#     106 if y_type in ["binary", "multiclass"]:
#     107     y_true = column_or_1d(y_true)
#
# ValueError: unknown is not supported

# %%
evaluation.get_performance(model=xgb,
                           pred_labels=le.inverse_transform(y_pred_train), 
                           true_labels=le.inverse_transform(y_train),
                           probs=probs_train,
                           vectorizer=tfid_vectorizer,
                           average='micro',
                           tree= tree_dict)
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.9452028269919643
# Precision: 0.9452028269919643
# Recall: 0.9452028269919643
# F1 Score: 0.9452028269919643
# Average distance between nodes categories: 0.10823893890986543
# Top 5 Score: 0.02369542066027689
#
# Model Classification report:
# ------------------------------
#                                            precision    recall  f1-score   support
#
#                       3D Printer Filament       0.99      0.96      0.98       190
#                   A/V Cables & Connectors       0.97      0.99      0.98       361
#                   Action Camcorder Mounts       1.00      0.99      1.00       114
#            Activity Trackers & Pedometers       0.98      0.99      0.99       154
#               Adapters, Cables & Chargers       0.99      0.98      0.99       284
#                          Air Conditioners       1.00      0.97      0.99       114
#              Air Purifier Filters & Parts       0.99      1.00      0.99        83
#                             Air Purifiers       0.99      0.99      0.99        94
#                All Cell Phones with Plans       0.99      0.96      0.97       134
#                              All Desktops       1.00      1.00      1.00       351
#                        All Flat-Panel TVs       0.96      0.97      0.96       122
#                            All Headphones       0.96      0.80      0.87       106
#                               All Laptops       0.97      0.97      0.97       130
#                          All Memory Cards       1.00      0.96      0.98        90
#                            All Microwaves       0.98      1.00      0.99       236
#                 All Point & Shoot Cameras       0.97      0.98      0.97        95
#                              All Printers       1.00      0.99      1.00       197
#                         All Refrigerators       0.97      0.98      0.98       551
#                             All TV Stands       0.99      0.99      0.99       327
#                               All Tablets       0.99      0.99      0.99       183
#                  All Unlocked Cell Phones       1.00      1.00      1.00       244
#                       Antennas & Adapters       1.00      0.96      0.98        82
#                Apple Watch Bands & Straps       0.92      0.94      0.93       104
#             Appliance Parts & Accessories       0.98      0.99      0.99       250
#                                Appliances       0.97      0.93      0.95        81
#                                     Audio       0.98      0.97      0.97        94
#                                  Bakeware       0.98      1.00      0.99       143
#                       Best Buy Gift Cards       1.00      1.00      1.00       363
#                                Binoculars       0.99      1.00      1.00       149
#           Binoculars, Telescopes & Optics       1.00      0.99      0.99       162
#                                  Blenders       1.00      0.98      0.99       102
#             Bluetooth & Wireless Speakers       0.96      0.99      0.97       566
#                        Bookshelf Speakers       1.00      0.96      0.98        96
#                      Built-In Dishwashers       1.00      1.00      1.00       210
#                    CD & DVD Media Storage       0.99      0.98      0.98        98
#                   CD Players & Turntables       0.99      0.99      0.99        83
#                     Camcorder Accessories       1.00      0.93      0.96       142
#               Camera Bags, Cases & Straps       0.95      0.97      0.96       108
#                          Camera Batteries       0.98      0.99      0.99       175
#                  Camera Batteries & Power       0.98      0.98      0.98       102
#                            Car Amplifiers       1.00      0.99      0.99        98
#              Car Audio Installation Parts       0.97      0.96      0.96       207
#                              Car Chargers       1.00      0.98      0.99        82
#                     Car Electronics & GPS       0.98      0.98      0.98       172
#      Car Installation Parts & Accessories       0.99      0.94      0.96       112
#                              Car Speakers       0.98      0.96      0.97       113
#                      Car Stereo Receivers       1.00      1.00      1.00        96
#                            Car Subwoofers       0.99      0.98      0.98        94
#                                     Cases       0.95      0.97      0.96       211
#           Cases, Covers & Keyboard Folios       0.95      0.92      0.94       445
#                    Cell Phone Accessories       0.96      0.96      0.96       228
#              Cell Phone Batteries & Power       0.98      1.00      0.99       178
#                  Cell Phone Cases & Clips       0.97      0.97      0.97      1477
#                               Cell Phones       0.97      0.98      0.97       204
#                              Single Ovens       0.94      0.85      0.89        89
#  Slow Cookers, Crock Pots & Roaster Ovens       0.99      0.98      0.98       122
#                  Small Kitchen Appliances       1.00      0.96      0.98       293
#                          Smartwatch Bands       0.97      0.95      0.96       186
#                                  Software       0.96      0.93      0.94       306
#                                Sound Bars       1.00      1.00      1.00        90
#                       Speaker Accessories       1.00      0.96      0.98       146
#                                  Speakers       0.99      0.97      0.98       243
#                      Specialty Appliances       1.00      0.99      0.99       245
# Steamers, Rice Cookers & Pressure Cookers       0.99      0.97      0.98        98
#                  Surge Protectors & Power       0.99      0.98      0.99       106
#                                   Systems       0.98      0.96      0.97        85
#                         TV & Home Theater       1.00      0.97      0.98        90
#             TV & Home Theater Accessories       1.00      0.98      0.99       173
#                                 TV Mounts       0.99      0.99      0.99       178
#                TV, Movie & Character Toys       0.98      0.82      0.89       107
#                                       TVs       0.95      0.94      0.95        89
#                                   Tablets       0.99      0.98      0.98        84
#                     Telephone Accessories       1.00      1.00      1.00        90
#                Telephones & Communication       0.98      0.96      0.97       109
#                                  Toasters       1.00      1.00      1.00       116
#                                     Toner       0.98      0.99      0.98       267
#                              Toys to Life       0.93      0.90      0.92       198
#                      Toys, Games & Drones       1.00      0.99      0.99       220
#                        Tripods & Monopods       0.99      1.00      1.00       143
#                         USB Cables & Hubs       1.00      0.99      0.99        92
#                          USB Flash Drives       1.00      1.00      1.00       256
#             Universal Camera Bags & Cases       0.99      0.99      0.99       130
#           Vacuum & Floor Care Accessories       0.99      0.99      0.99       151
#              Vacuum Cleaners & Floor Care       1.00      0.99      0.99       278
#                    Video Game Accessories       0.94      0.72      0.81        88
#                               Video Games       0.80      0.48      0.60       230
#                                  Wall Art       0.99      0.99      0.99       100
#            Wall Chargers & Power Adapters       0.96      0.99      0.97        90
#                    Wall Mount Range Hoods       0.99      1.00      1.00       169
#                                Wall Ovens       0.87      0.95      0.91        94
#                          Washing Machines       1.00      1.00      1.00       106
#                                       Wii       0.86      0.21      0.34        90
#                            Xbox 360 Games       0.51      0.12      0.19       164
#                                  Xbox One       0.89      0.84      0.86        80
#                            Xbox One Games       0.50      0.21      0.30       172
#                 iPad & Tablet Accessories       0.95      0.94      0.95       238
#                           iPhone 6s Cases       0.97      0.99      0.98       171
#                      iPhone 6s Plus Cases       0.97      0.95      0.96       101
#                        iPhone Accessories       0.84      0.86      0.85       150
#                      iPhone Cases & Clips       0.96      0.98      0.97      1241
#             iPod & MP3 Player Accessories       0.99      0.96      0.97       115
#                                     other       0.94      0.90      0.92      2224
#
#                                  accuracy                           0.95     41316
#                                 macro avg       0.97      0.94      0.95     41316
#                              weighted avg       0.95      0.95      0.94     41316

# %%
df_labels = pd.read_csv('/home/app/src/model/experiments/exp2022-12-15 05:48:58.634262/labels.csv')
df_labels['features'] = tfid_vectorizer.inverse_transform(X_train)
check = df_labels[df_labels.pred_cat != df_labels.true_cat]
