# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
import time
from model.text_normalizer import normalize_corpus, stopword_list
from model import evaluation
from model.utils import decoder
from scripts.build_df import build_df
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from scripts import tree_utils

from sklearn.base import BaseEstimator, TransformerMixin
from joblib import dump, load

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/app/.local/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [nltk_data] Downloading package stopwords to /home/app/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 1. The dataset

# %% [markdown]
# ### 1.1.

# %%
df = build_df(json_path='data/products.json', 
             threshold=0, 
             preprocessed_csv=None
            )

# %%
df.head()
# Out:
#                                               name  \
# 0                Duracell - AAA Batteries (4-Pack)
# 1  Duracell - AA 1.5V CopperTop Batteries (4-Pack)
# 2                 Duracell - AA Batteries (8-Pack)
# 3            Energizer - MAX Batteries AA (4-Pack)
# 4                  Duracell - C Batteries (4-Pack)
#
#                                          description          leaf  max_depth  \
# 0  Compatible with select electronic devices; AAA...  abcat0208002          4
# 1  Long-lasting energy; DURALOCK Power Preserve t...  abcat0208002          4
# 2  Compatible with select electronic devices; AA ...  abcat0208002          4
# 3  4-pack AA alkaline batteries; battery tester i...  abcat0208002          4
# 4  Compatible with select electronic devices; C s...  abcat0208002          4
#
#                                                 path  \
# 0  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 1  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 2  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 3  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 4  [pcmcat312300050015, pcmcat248700050021, pcmca...
#
#                                                image  \
# 0  http://www.bestbuy.com/site/duracell-aaa-batte...
# 1  http://www.bestbuy.com/site/duracell-aa-1-5v-c...
# 2  http://www.bestbuy.com/site/duracell-aa-batter...
# 3  http://www.bestbuy.com/site/energizer-max-batt...
# 4  http://www.bestbuy.com/site/duracell-c-batteri...
#
#                                          nm_and_desc  \
# 0  Duracell - AAA Batteries (4-Pack) Compatible w...
# 1  Duracell - AA 1.5V CopperTop Batteries (4-Pack...
# 2  Duracell - AA Batteries (8-Pack) Compatible wi...
# 3  Energizer - MAX Batteries AA (4-Pack) 4-pack A...
# 4  Duracell - C Batteries (4-Pack) Compatible wit...
#
#                                             category          category_0  \
# 0  [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 1  [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 2  [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 3  [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 4  [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
#
#            category_1          category_2    category_3 category_4 category_5  \
# 0  pcmcat248700050021  pcmcat303600050001  abcat0208002        NaN        NaN
# 1  pcmcat248700050021  pcmcat303600050001  abcat0208002        NaN        NaN
# 2  pcmcat248700050021  pcmcat303600050001  abcat0208002        NaN        NaN
# 3  pcmcat248700050021  pcmcat303600050001  abcat0208002        NaN        NaN
# 4  pcmcat248700050021  pcmcat303600050001  abcat0208002        NaN        NaN
#
#   category_6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# This function adds columns with path, level, and leaf to the original data, we decided to save the original columns and only the added `nm_and_desc` column  in a csv file called `data/products_v1.csv`
#
# **Note**: new columns created by the function but not saved in the file are related to the target label, and we deal with them in further steps.

# %% [markdown]
# ## 2. Features Normalization

# %%
df[['name', 'description', 'nm_and_desc', 'category', 'image']].to_csv('data/products_v1.csv',index=False)

# %% [markdown]
# `name` , `description` and `nm_and_desc` are the columns that we are going to use for training our different models and it is necessary that those columns be in normalized form. To do so, we apply our `normalization()` function and save the normalized data in another csv file: 'data/normalized_data.csv'
#
# In this way, the normalized data is available for different training processes avoiding unnecessary runs of the `normalization()` function. Re-running is reserved only for those cases when we want to try a different kind of normalization.

# %%
df = pd.read_csv('data/products_v1.csv')

def normalization(input):
    output = normalize_corpus(
        input,
        html_stripping=True,
        contraction_expansion=True,
        accented_char_removal=True,
        text_lower_case=True,
        text_stemming=True,
        text_lemmatization=False,
        special_char_removal=True,
        remove_digits=False,
        stopword_removal=True,
        stopwords=stopword_list
    )       
    return output

# Normalize the features 
df['name'] = normalization(df['name'].apply(str))
df['description'] = normalization(df['description'].apply(str))
df['name_and_description'] = [' '.join(i) for i in zip(df['name'], df['description'])]

#Saved the normalized data in a csv file
#### WARNING####
# IF YOU ARE GOING TO TRY ANOTHER KIND OF NORMALIZATION, PLEASE CHANGE THE NAME OF THE OUTPUT FILE IN ORDER TO AVOID OVERWRITING

normalized_data = df.to_csv('data/normalized_data.csv', index=False)

# %% [markdown]
# In future training you will be able to proceed without performing again the normalization step:
#
# ```python
#
# df = pd.read_csv('data/normalized_data.csv')
#
# name = df['name'].apply(str)
# description = df['description'].apply(str)
# name_and_description = df['name_and_description'].apply(str)
#
# # Select X depending on which data you are going to use to train your model
# X = name
# ```

# %% [markdown]
# ## 3. Labels and features selection
# `X` will vary depending if we choose name, description or name_and_description as feature.
#
# **Features:**

# %%
name = df['name'].apply(str)
description = df['description'].apply(str)
name_and_description = df['name_and_description'].apply(str)
X = name

# %% [markdown]
# **Labels**
#
# `build_df()` function returns a new dataset with custom leaf (label) according to the threshold of min. products selected per category.
#
# Call `build_df()` to extract the labels

# %%
cat = build_df(json_path='data/products.json', 
             threshold=100, 
             preprocessed_csv='data/normalized_data.csv'
            )

# %%
y = cat['leaf']

# %% [markdown]
# Recreating the hierarchical structure of our categories applying our `make_tree()` function
#
# We extracted the nodes from the same dataframe generated by `build_df()`

# %%
tree_dict = tree_utils.make_tree(cat, cat['category'], 'Categories', display_tree= True)
# Out:
# Categories
# ├── pcmcat312300050015
# │   ├── pcmcat248700050021
# │   │   ├── pcmcat303600050001
# │   │   └── pcmcat179100050006
# │   │       ├── pcmcat179200050003
# │   │       ├── pcmcat179200050008
# │   │       │   └── pcmcat748300322875
# │   │       └── pcmcat179200050013
# │   ├── abcat0802000
# │   │   ├── abcat0811011
# │   │   └── abcat0802001
# │   │       └── pcmcat159300050002
# │   ├── abcat0805000
# │   │   └── abcat0511001
# │   │       └── pcmcat266500050030
# │   ├── pcmcat275600050000
# │   │   └── abcat0807000
# │   │       ├── abcat0807001
# │   │       ├── pcmcat335400050008
# │   │       └── abcat0807009
# │   ├── abcat0809000
# │   │   ├── abcat0809004
# │   │   └── abcat0809002
# │   ├── pcmcat249700050006
# │   │   ├── pcmcat219100050010
# │   │   ├── pcmcat286300050020
# │   │   └── pcmcat272800050000
# │   ├── pcmcat254000050002
# │   │   └── pcmcat308100050020
# │   │       └── pcmcat340500050007
# │   └── pcmcat341100050005
# │       └── pcmcat253700050018
# │           └── pcmcat248300050003
# ├── other
# ├── abcat0300000
# │   ├── pcmcat165900050023
# │   │   └── pcmcat331600050007
# │   │       └── pcmcat165900050031
# │   │           ├── pcmcat165900050033
# │   │           ├── pcmcat165900050034
# │   │           └── pcmcat165900050032
# │   ├── abcat0302000
# │   │   ├── abcat0302034
# │   │   │   └── abcat0302037
# │   │   ├── abcat0302001
# │   │   ├── abcat0302012
# │   │   └── abcat0302005
# │   ├── pcmcat156300050006
# │   └── abcat0301000
# ├── abcat0207000
# │   ├── pcmcat152100050020
# │   ├── abcat0208024
# │   │   └── pcmcat151600050008
# │   ├── pcmcat152100050035
# │   │   └── pcmcat251600050003
# │   │       └── pcmcat152100050038
# │   ├── pcmcat151600050037
# │   ├── pcmcat152100050027
# │   ├── pcmcat152200050014
# │   │   ├── pcmcat202800050013
# │   │   └── pcmcat251500050009
# │   ├── pcmcat152100050010
# │   └── pcmcat151600050019
# │       └── pcmcat221400050011
# │           └── pcmcat151600050027
# ├── pcmcat252700050006
# │   ├── pcmcat244200050008
# │   ├── pcmcat284400050091
# │   └── pcmcat369900050001
# ├── abcat0700000
# │   ├── abcat0706000
# │   ├── abcat0701000
# │   │   └── abcat0701002
# │   ├── pcmcat232900050017
# │   ├── abcat0707000
# │   │   └── abcat0707002
# │   ├── abcat0703000
# │   │   └── abcat0703002
# │   ├── abcat0712000
# │   ├── pcmcat232900050000
# │   ├── abcat0715000
# │   ├── pcmcat295700050012
# │   │   └── pcmcat296300050018
# │   ├── pcmcat300300050002
# │   │   └── pcmcat303600050005
# │   └── pcmcat306400050032
# ├── abcat0400000
# │   ├── abcat0401000
# │   │   └── abcat0401001
# │   │       └── pcmcat324200050004
# │   ├── abcat0410022
# │   │   └── pcmcat329700050009
# │   │       └── pcmcat240500050057
# │   ├── abcat0410000
# │   │   ├── abcat0410018
# │   │   │   ├── pcmcat233000050008
# │   │   │   │   └── pcmcat195200050001
# │   │   │   └── pcmcat374500050006
# │   │   ├── abcat0410020
# │   │   ├── abcat0410012
# │   │   │   └── pcmcat284800050007
# │   │   ├── pcmcat284800050006
# │   │   │   └── abcat0410001
# │   │   │       └── pcmcat328900050008
# │   │   ├── abcat0410045
# │   │   └── pcmcat240500050025
# │   │       └── pcmcat240500050052
# │   ├── abcat0404000
# │   │   └── pcmcat225800050009
# │   └── abcat0409000
# │       └── abcat0409001
# ├── abcat0500000
# │   ├── abcat0515000
# │   │   ├── abcat0515042
# │   │   ├── pcmcat221100050003
# │   │   ├── abcat0515025
# │   │   │   ├── pcmcat183800050007
# │   │   │   ├── pcmcat183800050006
# │   │   │   └── abcat0515028
# │   │   ├── abcat0513000
# │   │   │   ├── pcmcat338200050008
# │   │   │   └── abcat0513004
# │   │   ├── abcat0504001
# │   │   │   └── pcmcat186100050005
# │   │   ├── abcat0504010
# │   │   └── abcat0515012
# │   │       └── abcat0515013
# │   ├── abcat0507000
# │   ├── pcmcat309900050001
# │   │   └── pcmcat242000050002
# │   │       └── pcmcat344400050007
# │   ├── abcat0509000
# │   │   └── pcmcat200900050014
# │   ├── abcat0508000
# │   ├── pcmcat209000050006
# │   │   └── pcmcat209000050008
# │   ├── abcat0503000
# │   ├── abcat0502000
# │   │   └── pcmcat138500050001
# │   │       └── pcmcat247400050000
# │   └── abcat0501000
# │       └── pcmcat143400050013
# ├── abcat0900000
# │   ├── abcat0904000
# │   │   ├── abcat0904001
# │   │   ├── abcat0904004
# │   │   │   └── pcmcat180700050008
# │   │   ├── abcat0904003
# │   │   │   ├── pcmcat196400050015
# │   │   │   └── pcmcat196400050016
# │   │   └── abcat0904002
# │   │       └── pcmcat207200050007
# │   ├── abcat0912000
# │   │   ├── pcmcat367400050002
# │   │   │   ├── pcmcat367400050005
# │   │   │   │   └── abcat0912008
# │   │   │   ├── abcat0912005
# │   │   │   │   └── pcmcat258900050007
# │   │   │   └── pcmcat367400050003
# │   │   │       └── pcmcat194000050023
# │   │   ├── abcat0912011
# │   │   │   └── pcmcat194000050018
# │   │   │       └── pcmcat258900050003
# │   │   ├── abcat0912014
# │   │   ├── abcat0912025
# │   │   │   └── pcmcat251300050004
# │   │   ├── abcat0912023
# │   │   ├── abcat0912012
# │   │   ├── abcat0912020
# │   │   ├── pcmcat748301695371
# │   │   │   ├── pcmcat226900050013
# │   │   │   └── pcmcat748301695443
# │   │   ├── abcat0912018
# │   │   └── pcmcat194000050022
# │   ├── abcat0902000
# │   ├── pcmcat302300050021
# │   │   ├── abcat0907001
# │   │   ├── abcat0907007
# │   │   ├── abcat0908003
# │   │   ├── abcat0908001
# │   │   ├── pcmcat268100050002
# │   │   └── abcat0907006
# │   ├── abcat0901000
# │   │   └── pcmcat367400050001
# │   ├── abcat0903000
# │   │   └── pcmcat748301803023
# │   ├── abcat0910000
# │   │   ├── abcat0910004
# │   │   │   ├── pcmcat232900050031
# │   │   │   └── pcmcat232900050030
# │   │   └── abcat0910001
# │   ├── abcat0911000
# │   ├── abcat0905000
# │   │   └── abcat0905001
# │   └── abcat0916000
# │       ├── pcmcat303700050016
# │       └── abcat0916008
# ├── abcat0200000
# │   ├── abcat0204000
# │   │   ├── pcmcat144700050004
# │   │   ├── pcmcat143000050011
# │   │   │   ├── pcmcat331200050001
# │   │   │   └── pcmcat331200050000
# │   │   └── pcmcat143000050007
# │   ├── pcmcat241600050001
# │   │   ├── pcmcat309300050002
# │   │   ├── abcat0205000
# │   │   │   ├── abcat0205006
# │   │   │   ├── pcmcat210900050000
# │   │   │   │   └── pcmcat210900050001
# │   │   │   └── abcat0205001
# │   │   ├── abcat0203000
# │   │   │   └── abcat0205007
# │   │   └── pcmcat309300050003
# │   ├── abcat0208007
# │   ├── pcmcat310200050004
# │   └── abcat0208000
# │       └── abcat0208015
# ├── abcat0100000
# │   ├── abcat0106000
# │   │   ├── pcmcat332100050008
# │   │   │   └── pcmcat158900050019
# │   │   ├── abcat0106004
# │   │   ├── abcat0106001
# │   │   │   └── pcmcat332100050000
# │   │   └── abcat0106010
# │   ├── abcat0107000
# │   │   └── abcat0107015
# │   ├── abcat0101000
# │   │   └── abcat0101001
# │   └── pcmcat158900050008
# │       └── pcmcat158900050018
# ├── pcmcat242800050021
# │   ├── abcat0915000
# │   │   ├── abcat0915009
# │   │   └── abcat0915005
# │   ├── pcmcat352500050007
# │   ├── abcat0301006
# │   └── pcmcat210000050008
# ├── pcmcat128500050004
# ├── abcat0800000
# │   ├── abcat0811002
# │   │   ├── abcat0811006
# │   │   ├── pcmcat191200050015
# │   │   │   └── pcmcat214700050000
# │   │   │       ├── pcmcat748300579994
# │   │   │       └── pcmcat748300580023
# │   │   ├── abcat0811004
# │   │   │   ├── pcmcat326000050010
# │   │   │   └── pcmcat326000050011
# │   │   ├── pcmcat373300050003
# │   │   ├── abcat0811007
# │   │   │   ├── pcmcat171900050026
# │   │   │   └── pcmcat171900050024
# │   │   ├── pcmcat171900050031
# │   │   └── pcmcat321000050003
# │   │       └── pcmcat321000050005
# │   │           └── pcmcat350800050010
# │   ├── pcmcat156400050037
# │   │   └── pcmcat311200050005
# │   └── pcmcat209400050001
# ├── cat09000
# ├── pcmcat139900050002
# │   └── pcmcat748300660981
# │       └── pcmcat143200050025
# └── pcmcat332000050000
#     └── pcmcat748300489081
#         └── pcmcat377500050002
#             └── pcmcat377500050003

# %% [markdown]
# **IMPORTANT**:
# - Generate the labels and the tree in the **same step**. If you do not do that you will not be allowed to get the distance between predicted and true categories when apply `get_performance()` function
#
# - `make_tree()` print the tree if you set `display_tree= True`. `display_tree= False` only generates the tree structure (without printing it) and the dictionary of nodes

# %%
tree_dict2 = tree_utils.make_tree(cat, cat['category'], 'Categories', display_tree= False)

# %% [markdown]
# ## 4. Train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20, 
    random_state=42,
    stratify = y
)

# %% [markdown]
# ## 5. Feature engineering
# Try different values for `max_features` and `ngram_range` in TF-IDF. Also experimenting with and without IDF and min and max idf values.

# %%
tfid_vectorizer = TfidfVectorizer(max_features=1500, 
                                  ngram_range=(1, 3),
                                  use_idf=False,
                                  min_df=1,
                                  norm='l2',
                                  smooth_idf=True
                                 ) 
X_train = tfid_vectorizer.fit_transform(X_train)
X_test = tfid_vectorizer.transform(X_test)

# %% [markdown]
# ## 6. Modeling
# In this sample notebook we train a logistic regressor

# %%
logreg = LogisticRegression(max_iter=2000, 
                            n_jobs=-1, 
                            multi_class='multinomial', 
                            solver='newton-cg')

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000, multi_class='multinomial', n_jobs=-1,
#                    solver='newton-cg')

# %% [markdown]
# ## 7. Evaluation

# %%
y_pred_test = logreg.predict(X_test)

# %% [markdown]
# We now apply `get_performance()` function, from which we can obtain all the relevant metrics. All the information is saved in a new folder containing different files in `model/experiments`.
#
# The name of each experiment folder corresponds to the date and time on which the experiment was performed

# %% [markdown]
# **Note**: 13/12/22 version of this function adds tree functionality giving the distance between predicted and true labels. It also calculates the average value of such distance.

# %%
evaluation.get_performance(model=logreg,
                           pred_labels=y_pred_test, 
                           true_labels=y_test,
                           vectorizer=tfid_vectorizer,
                           average='micro',
                           tree= tree_dict)
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.7820909970958374
# Precision: 0.7820909970958374
# Recall: 0.7820909970958374
# F1 Score: 0.7820909970958374
# Average distance between nodes categories: 0.4915779283639884
#
# Model Classification report:
# ------------------------------
#                                            precision    recall  f1-score   support
#
#                       3D Printer Filament       0.85      1.00      0.92        47
#                   A/V Cables & Connectors       0.67      0.78      0.72        90
#                   Action Camcorder Mounts       0.52      0.57      0.54        28
#            Activity Trackers & Pedometers       0.89      0.85      0.87        39
#               Adapters, Cables & Chargers       0.63      0.73      0.68        71
#                          Air Conditioners       0.96      0.96      0.96        28
#              Air Purifier Filters & Parts       1.00      0.76      0.86        21
#                             Air Purifiers       0.88      0.88      0.88        24
#                All Cell Phones with Plans       0.93      0.85      0.89        33
#                              All Desktops       0.93      0.95      0.94        88
#                        All Flat-Panel TVs       0.92      0.74      0.82        31
#                            All Headphones       1.00      0.04      0.07        26
#                               All Laptops       0.81      0.88      0.84        33
#                          All Memory Cards       0.73      0.73      0.73        22
#                            All Microwaves       0.98      1.00      0.99        59
#                 All Point & Shoot Cameras       0.77      0.96      0.85        24
#                              All Printers       0.98      0.94      0.96        49
#                         All Refrigerators       0.71      0.83      0.76       138
#                             All TV Stands       0.77      0.91      0.84        82
#                               All Tablets       0.90      0.98      0.94        46
#                  All Unlocked Cell Phones       0.98      1.00      0.99        61
#                       Antennas & Adapters       1.00      0.81      0.89        21
#                Apple Watch Bands & Straps       0.92      0.85      0.88        26
#             Appliance Parts & Accessories       0.75      0.53      0.62        62
#                                Appliances       0.87      0.65      0.74        20
#                                     Audio       0.79      0.83      0.81        23
#                                  Bakeware       0.84      0.75      0.79        36
#                       Best Buy Gift Cards       0.93      0.97      0.95        91
#                                Binoculars       1.00      0.97      0.99        37
#           Binoculars, Telescopes & Optics       0.90      0.93      0.91        40
#                                  Blenders       0.88      0.60      0.71        25
#             Bluetooth & Wireless Speakers       0.78      0.92      0.84       142
#                        Bookshelf Speakers       0.94      0.71      0.81        24
#                      Built-In Dishwashers       1.00      1.00      1.00        53
#                    CD & DVD Media Storage       0.72      0.72      0.72        25
#                   CD Players & Turntables       0.77      0.81      0.79        21
#                     Camcorder Accessories       0.54      0.20      0.29        35
#               Camera Bags, Cases & Straps       0.71      0.63      0.67        27
#                          Camera Batteries       0.67      0.91      0.77        44
#                  Camera Batteries & Power       0.75      0.60      0.67        25
#                            Car Amplifiers       0.92      0.92      0.92        24
#              Car Audio Installation Parts       0.78      0.60      0.67        52
#                              Car Chargers       0.65      0.65      0.65        20
#                     Car Electronics & GPS       0.57      0.47      0.51        43
#      Car Installation Parts & Accessories       0.67      0.14      0.24        28
#                              Car Speakers       0.89      0.89      0.89        28
#                      Car Stereo Receivers       0.88      0.96      0.92        24
#                            Car Subwoofers       0.79      0.83      0.81        23
#                                     Cases       0.78      0.79      0.79        53
#           Cases, Covers & Keyboard Folios       0.77      0.88      0.82       112
#                    Cell Phone Accessories       0.63      0.51      0.56        57
#              Cell Phone Batteries & Power       0.50      0.41      0.45        44
#                  Cell Phone Cases & Clips       0.88      0.91      0.90       370
#                               Cell Phones       0.89      0.80      0.85        51
#                             Coffee Makers       0.53      0.40      0.46        20
#                               Coffee Pods       0.95      0.95      0.95        21
#                    Coffee, Tea & Espresso       0.73      0.59      0.65        46
#        Computer Accessories & Peripherals       0.81      0.46      0.59        37
# Steamers, Rice Cookers & Pressure Cookers       0.77      0.71      0.74        24
#                  Surge Protectors & Power       0.81      0.78      0.79        27
#                                   Systems       0.68      1.00      0.81        21
#                         TV & Home Theater       0.71      0.65      0.68        23
#             TV & Home Theater Accessories       0.72      0.60      0.66        43
#                                 TV Mounts       0.95      0.87      0.91        45
#                TV, Movie & Character Toys       0.76      0.48      0.59        27
#                                       TVs       0.69      0.82      0.75        22
#                                   Tablets       1.00      0.81      0.89        21
#                     Telephone Accessories       1.00      0.73      0.84        22
#                Telephones & Communication       0.75      0.67      0.71        27
#                                  Toasters       0.94      1.00      0.97        29
#                                     Toner       0.88      0.87      0.87        67
#                              Toys to Life       0.81      0.96      0.88        49
#                      Toys, Games & Drones       0.61      0.56      0.58        55
#                        Tripods & Monopods       0.84      0.44      0.58        36
#                         USB Cables & Hubs       0.56      0.83      0.67        23
#                          USB Flash Drives       0.98      0.98      0.98        64
#             Universal Camera Bags & Cases       0.65      0.73      0.69        33
#           Vacuum & Floor Care Accessories       0.63      0.45      0.52        38
#              Vacuum Cleaners & Floor Care       0.86      0.88      0.87        69
#                    Video Game Accessories       0.57      0.36      0.44        22
#                               Video Games       0.56      0.31      0.40        58
#                                  Wall Art       0.96      0.92      0.94        25
#            Wall Chargers & Power Adapters       0.62      0.45      0.53        22
#                    Wall Mount Range Hoods       0.89      1.00      0.94        42
#                                Wall Ovens       0.96      1.00      0.98        23
#                          Washing Machines       1.00      1.00      1.00        27
#                                       Wii       0.55      0.70      0.62        23
#                            Xbox 360 Games       0.86      0.90      0.88        41
#                                  Xbox One       0.85      0.85      0.85        20
#                            Xbox One Games       0.93      0.98      0.95        43
#                 iPad & Tablet Accessories       0.85      0.57      0.68        60
#                           iPhone 6s Cases       0.83      0.56      0.67        43
#                      iPhone 6s Plus Cases       0.56      0.36      0.44        25
#                        iPhone Accessories       0.73      0.30      0.42        37
#                      iPhone Cases & Clips       0.76      0.96      0.85       311
#             iPod & MP3 Player Accessories       0.67      0.28      0.39        29
#                                     other       0.38      0.62      0.47       556
#
#                                  accuracy                           0.78     10330
#                                 macro avg       0.80      0.74      0.76     10330
#                              weighted avg       0.79      0.78      0.78     10330

# %% [markdown]
# ## 8. EDA post prediction

# %%
df_labels = pd.read_csv('/home/app/src/model/experiments/exp2022-12-13 20:15:10.910496/labels.csv')

# %%
df_labels.head()
# Out:
#              pred_cat            true_cat                 pred_cat_dec  \
# 0  pcmcat151600050037  pcmcat151600050037                    Keyboards
# 1        abcat0912008        abcat0912008                  Coffee Pods
# 2        abcat0507000        abcat0507000  Computer Cards & Components
# 3  pcmcat183800050006  pcmcat183800050006             Laptop Batteries
# 4  pcmcat152100050038  pcmcat152100050020                  Microphones
#
#                   true_cat_dec  dist
# 0                    Keyboards     0
# 1                  Coffee Pods     0
# 2  Computer Cards & Components     0
# 3             Laptop Batteries     0
# 4          Recording Equipment     3

# %%
df_labels['dist'].value_counts()
# Out:
# 0    8079
# 1     698
# 2     671
# 3     534
# 4     304
# 5      44
# Name: dist, dtype: int64
