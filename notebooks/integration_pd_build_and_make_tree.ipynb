# %% [markdown]
# ## Integrating `build_df()`, `make_tree()` and `dist_nodes()`

# %%
import json
import pandas as pd
import numpy as np

from anytree import Node
from anytree import RenderTree, find, find_by_attr, findall

# %% [markdown]
# ### Modifying our `build_df()` function
#
# In the first stage, we made our buil_df() function that allows us to create a dataset according to a given threshold for the minimum amount products per category.
#
# The second step was to create a function to take into account different aspects of the tree structure of the category products. To this end, we made make_tree() and  dist_nodes() functions, which capture the tree structure and the distance between nodes of that structure respectively.
#
# As the third step, we need to integrate our different functions. To do so, we add the "category" entry of product.json as a column of the data frame to be generated by our build_df() function and dismiss those entries (categories and subcategories)  below the threshold parameter.

# %%
# Conditions for creating the "leaf" column
def conditions_leaf(row, number_of_categories_columns):
    if row["category_0"] == "other":
        return "other"
    for i in reversed(range(number_of_categories_columns)):
        if type(row["category_" + str(i)]) == str and row["category_" + str(i)] != 'other':
            return row["category_" + str(i)]

# Conditions for creating the "max_depth" column
def conditions_max_depth(row, number_of_categories_columns):
    if row["path"] == str:
        return 1
    return len(row["path"])


# Conditions for creating the "path" column
def conditions_path(row, number_of_categories_columns):
    path = []
    if row["category_0"] == "other":
        return "other"
    for i in range(number_of_categories_columns):
        if type(row["category_" + str(i)]) == str and row["category_" + str(i)] != 'other':
            path.append(row["category_" + str(i)])
    return path


# Get "category_" columns list
def get_category_columns(df):    
    category_columns = []
    for column in df.columns:
            if column.startswith("category_"):
                category_columns.append(column)
    return category_columns




def build_df(json_path: str, threshold: int, preprocessed_csv: str = None): 
    # Save json into dict
    with open(json_path) as f:
        products_dic = json.load(f)
    
    # Create base DataFrame
    all_cats_dict = []
    for dic in products_dic:
        new_dict = {}
        new_dict

        if preprocessed_csv == None:
            # Add name and description
            new_dict["name"] = dic["name"]
            new_dict["description"] = dic["description"]
        
        # Add category (list of dict) to be used by make_tree()
        new_dict['category'] = dic['category']

        # Add category names respecting hierarchy
        for i in range(len(dic["category"])):
            new_dict["category_" + str(i)] = dic["category"][i]["id"]
        all_cats_dict.append(new_dict)
    
    df = pd.DataFrame(all_cats_dict)
    
    if preprocessed_csv != None:
        df.insert(0, "name", pd.read_csv(preprocessed_csv)["name"])
        df.insert(1, "description", pd.read_csv(preprocessed_csv)["description"])
    
    # Get number of category columns
    number_of_categories_columns = len(get_category_columns(df))
    
    # Replace leaf category with "other" according to threshold
    for i in range(number_of_categories_columns):
        level = df["category_" + str(i)].copy()
        level_count_series = level.value_counts()
        categories_within_threshold = level_count_series[level_count_series > threshold].reset_index()["index"]
        is_category_in_threshold_and_not_nan = ~(~level.isin(categories_within_threshold) & level.notna())
        df["category_" + str(i)] = level.where(is_category_in_threshold_and_not_nan, 'other')

    # "path" column, with a list of all the categories from root to leaf
    df.insert(2,"path",df.apply(lambda row: conditions_path(row, number_of_categories_columns), axis=1))

    # "leaf" column, excluding "other" unless it's a root category
    df.insert(2,"leaf",df.apply(lambda row: conditions_leaf(row, number_of_categories_columns), axis=1))
    
    # "max_depth" column
    df.insert(3,"max_depth",df.apply(lambda row: conditions_max_depth(row, number_of_categories_columns), axis=1))
    
    # Modify category column to be used by make_tree() according to threshold. For those entries below the threshold we assign the following one-entry dictionary
    other_dict = [{'id': 'other', 'name': 'other'}]
    df['category'] = df.apply(lambda row: row.category[0: len(row.path)] if row.path != 'other' else other_dict, axis = 1)

    # Change "other" for np.nan
    df_nan = df.copy()
    for column in get_category_columns(df_nan):
        df_nan[column] = df_nan[column].apply(lambda x: np.nan if x == "other" else x)
    
    return df_nan

# %%
df_int = build_df("../data/products.json", 100)

# %%
df_int[5:20]
# Out:
#                                                  name  \
# 5                     Duracell - D Batteries (4-Pack)
# 6                    Duracell - 9V Batteries (2-Pack)
# 7   Directed Electronics - Viper Audio Glass Break...
# 8           Energizer - N Cell E90 Batteries (2-Pack)
# 9   Metra - Radio Installation Dash Kit for Most 1...
# 10  Metra - Radio Dash Multikit for Select GM Vehi...
# 11  Metra - Wiring Harness for Select 1998-2008 Fo...
# 12  Metra - Turbo Wire Aftermarket Radio Wire Harn...
# 13  Metra - Wiring Harness for Most 1986-1998 Hond...
# 14              METRA - Antenna Cable Adapter - Black
# 15             INSTALL - PORTABLE RADAR DETECTOR INST
# 16      Jensen - 3.6V NiCad Battery for 900MHz Phones
# 17  Metra - Radio Installation Dash Kit for Select...
# 18       Metra - 1/4" DIN Trim Ring for Most Vehicles
# 19  Metra - Turbowire Radio Harness Adapter for Se...
#
#                                           description                leaf  \
# 5   Compatible with select electronic devices; D s...  pcmcat303600050001
# 6   Compatible with select electronic devices; alk...  pcmcat303600050001
# 7   From our expanded online assortment; compatibl...               other
# 8                            Alkaline batteries; 1.5V  pcmcat303600050001
# 9   From our expanded online assortment; compatibl...  pcmcat165900050033
# 10  From our expanded online assortment; compatibl...  pcmcat165900050033
# 11  Compatible with select 1998-2008 Ford vehicles...  pcmcat165900050034
# 12  Compatible with Honda and Acura vehicles; conn...  pcmcat165900050034
# 13  Compatible with most 1986-1998 Honda Acura veh...  pcmcat165900050034
# 14  Compatible with select 1988-2005 vehicles; ada...  pcmcat165900050032
# 15                       PORTABLE RADAR DETECTOR INST               other
# 16  Rechargeable 3.6V 300 mAh NiCad battery for GE...        abcat0811011
# 17  From our expanded online assortment; compatibl...  pcmcat165900050033
# 18  Compatible with most vehicles; designed for th...  pcmcat165900050033
# 19  Compatible with select Jeep vehicles; ABS and ...  pcmcat165900050034
#
#     max_depth                                               path  \
# 5           3  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 6           3  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 7           5                                              other
# 8           3  [pcmcat312300050015, pcmcat248700050021, pcmca...
# 9           5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 10          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 11          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 12          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 13          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 14          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 15          5                                              other
# 16          3   [pcmcat312300050015, abcat0802000, abcat0811011]
# 17          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 18          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
# 19          5  [abcat0300000, pcmcat165900050023, pcmcat33160...
#
#                                              category          category_0  \
# 5   [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 6   [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 7                  [{'id': 'other', 'name': 'other'}]                 NaN
# 8   [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 9   [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 10  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 11  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 12  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 13  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 14  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 15                 [{'id': 'other', 'name': 'other'}]                 NaN
# 16  [{'id': 'pcmcat312300050015', 'name': 'Connect...  pcmcat312300050015
# 17  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 18  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
# 19  [{'id': 'abcat0300000', 'name': 'Car Electroni...        abcat0300000
#
#             category_1          category_2          category_3  \
# 5   pcmcat248700050021  pcmcat303600050001                 NaN
# 6   pcmcat248700050021  pcmcat303600050001                 NaN
# 7                  NaN                 NaN                 NaN
# 8   pcmcat248700050021  pcmcat303600050001                 NaN
# 9   pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 10  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 11  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 12  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 13  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 14  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 15                 NaN                 NaN                 NaN
# 16        abcat0802000        abcat0811011                 NaN
# 17  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 18  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
# 19  pcmcat165900050023  pcmcat331600050007  pcmcat165900050031
#
#             category_4  category_5  category_6
# 5                  NaN         NaN         NaN
# 6                  NaN         NaN         NaN
# 7                  NaN         NaN         NaN
# 8                  NaN         NaN         NaN
# 9   pcmcat165900050033         NaN         NaN
# 10  pcmcat165900050033         NaN         NaN
# 11  pcmcat165900050034         NaN         NaN
# 12  pcmcat165900050034         NaN         NaN
# 13  pcmcat165900050034         NaN         NaN
# 14  pcmcat165900050032         NaN         NaN
# 15                 NaN         NaN         NaN
# 16                 NaN         NaN         NaN
# 17  pcmcat165900050033         NaN         NaN
# 18  pcmcat165900050033         NaN         NaN
# 19  pcmcat165900050034         NaN         NaN

# %% [markdown]
# ### Applying `make_tree()`function
#
# Here we apply our `make_tree()` function to the data frame created by our modified `build_df()` function:

# %%
def make_tree(df, df_column_cat, root_name):
  
  """Takes a data frame, a column of such dataframe and a string name
  Using anytree library generate the tree and print it, and return a dictionary 
  
  Parameters:
  df = a column data frame
  df_column_cat: a column of a data frame which values are a simple dictinary or a list of them
  root_name: str
  
  print the tree and
  Returns a dictionary with category name:str as keys and nodes as values 
  """
  #set the root node
  root = Node(root_name)
  # list of nodes to be generated by the function
  nodes = {}
  nodes[root.name]: root
  # Iteration over rows
  for index, row in df.iterrows():
  # Iteration over index of values at each row
    c = df_column_cat[index]
    for i_cat in range(len(c)):
      #cat_name = c[i_cat]['id'] 
      cat_name = c[i_cat]['id'] + ' '+ c[i_cat]['name'] # If you want to display the id along with category names uncomment this line and comment the previous one

      # Verify if the parent category exist if it does not exists appends it to the nodes list and creates the node. Else continues
      if i_cat == 0 and cat_name not in nodes:
        nodes[cat_name] = Node(cat_name, parent=find_by_attr(root, root_name))

      # Verify if the subcategory exists if it does not exists appends it to the nodes list and creates the node. Else continues  
      elif i_cat > 0 and cat_name not in nodes:
        #predecessor = c[i_cat -1]['id'] 
        predecessor = c[i_cat - 1]['id'] + ' '+ c[i_cat-1]['name'] # If you want to display the id along with category names uncomment this line and comment the previous one
        nodes[cat_name] = Node(cat_name, find_by_attr(root,predecessor))
      
      else: continue
   
  for pre, _, node in RenderTree(root):
    print("%s%s" % (pre, node.name))
    
  return nodes

# %%
tree_dict = make_tree(df_int, df_int['category'], "Categories")
# Out:
# Categories
# ├── pcmcat312300050015 Connected Home & Housewares
# │   ├── pcmcat248700050021 Housewares
# │   │   ├── pcmcat303600050001 Household Batteries
# │   │   └── pcmcat179100050006 Outdoor Living
# │   │       ├── pcmcat179200050003 Grills
# │   │       ├── pcmcat179200050008 Patio Furniture & Decor
# │   │       │   └── pcmcat748300322875 Outdoor Seating
# │   │       └── pcmcat179200050013 Outdoor Heating
# │   ├── abcat0802000 Telephones & Communication
# │   │   ├── abcat0811011 Telephone Accessories
# │   │   └── abcat0802001 Cordless Telephones
# │   │       └── pcmcat159300050002 Systems
# │   ├── abcat0805000 Office Electronics
# │   │   └── abcat0511001 Printers, Ink & Toner
# │   │       └── pcmcat266500050030 All Printers
# │   ├── pcmcat275600050000 Office & School Supplies
# │   │   └── abcat0807000 Printer Ink & Toner
# │   │       ├── abcat0807001 Printer Ink
# │   │       ├── pcmcat335400050008 3D Printer Filament
# │   │       └── abcat0807009 Toner
# │   ├── abcat0809000 Office Furniture & Storage
# │   │   ├── abcat0809004 Desks
# │   │   └── abcat0809002 Office Chairs
# │   ├── pcmcat341100050005 Household Essentials
# │   │   └── pcmcat253700050018 Luggage, Bags & Travel
# │   │       └── pcmcat248300050003 Luggage
# │   ├── pcmcat249700050006 Furniture & Decor
# │   │   ├── pcmcat219100050010 Game Room & Bar Furniture
# │   │   ├── pcmcat286300050020 Wall Art
# │   │   └── pcmcat272800050000 Living Room Furniture
# │   └── pcmcat254000050002 Connected Home
# │       └── pcmcat308100050020 Security Cameras & Surveillance
# │           └── pcmcat340500050007 Security Camera Systems
# ├── other other
# ├── abcat0300000 Car Electronics & GPS
# │   ├── pcmcat165900050023 Car Installation Parts & Accessories
# │   │   └── pcmcat331600050007 Car Audio Installation Parts
# │   │       └── pcmcat165900050031 Deck Installation Parts
# │   │           ├── pcmcat165900050033 Dash Installation Kits
# │   │           ├── pcmcat165900050034 Deck Harnesses
# │   │           └── pcmcat165900050032 Antennas & Adapters
# │   ├── abcat0302000 Car Audio
# │   │   ├── abcat0302034 Car Subwoofers & Enclosures
# │   │   │   └── abcat0302037 Car Subwoofers
# │   │   ├── abcat0302001 Car Amplifiers
# │   │   ├── abcat0302012 Car Stereo Receivers
# │   │   └── abcat0302005 Car Speakers
# │   ├── pcmcat156300050006 Marine & Powersports
# │   └── abcat0301000 GPS Navigation & Accessories
# ├── abcat0207000 Musical Instruments
# │   ├── pcmcat152100050020 Recording Equipment
# │   ├── abcat0208024 Musical Instrument Accessories
# │   │   └── pcmcat151600050008 Guitar Accessories
# │   ├── pcmcat152100050035 Microphones & Live Sound
# │   │   └── pcmcat251600050003 Microphones & Accessories
# │   │       └── pcmcat152100050038 Microphones
# │   ├── pcmcat151600050037 Keyboards
# │   ├── pcmcat152100050027 DJ & Lighting Equipment
# │   ├── pcmcat152200050014 Sheet Music & DVDs
# │   │   ├── pcmcat202800050013 Sheet Music
# │   │   └── pcmcat251500050009 Instrument Instructional Books
# │   ├── pcmcat152100050010 Drums & Percussion
# │   └── pcmcat151600050019 Amps & Effects
# │       └── pcmcat221400050011 Effects
# │           └── pcmcat151600050027 Pedals
# ├── pcmcat252700050006 Toys, Games & Drones
# │   ├── pcmcat244200050008 TV, Movie & Character Toys
# │   ├── pcmcat284400050091 Learning & Education
# │   └── pcmcat369900050001 Drones & Accessories
# ├── abcat0700000 Video Games
# │   ├── abcat0706000 Wii
# │   ├── abcat0701000 Xbox 360
# │   │   └── abcat0701002 Xbox 360 Games
# │   ├── pcmcat232900050017 Pre-Owned Games
# │   ├── abcat0707000 Nintendo DS
# │   │   └── abcat0707002 Nintendo DS Games
# │   ├── abcat0703000 PlayStation 3
# │   │   └── abcat0703002 PS3 Games
# │   ├── abcat0712000 PC Gaming
# │   ├── pcmcat232900050000 Nintendo 3DS
# │   ├── abcat0715000 Video Game Accessories
# │   ├── pcmcat295700050012 PlayStation 4
# │   │   └── pcmcat296300050018 PS4 Games
# │   ├── pcmcat300300050002 Xbox One
# │   │   └── pcmcat303600050005 Xbox One Games
# │   └── pcmcat306400050032 Toys to Life
# ├── abcat0400000 Cameras & Camcorders
# │   ├── abcat0401000 Digital Cameras
# │   │   └── abcat0401001 Point & Shoot Cameras
# │   │       └── pcmcat324200050004 All Point & Shoot Cameras
# │   ├── abcat0410022 Camcorder Accessories
# │   │   └── pcmcat329700050009 Action Camcorder Accessories
# │   │       └── pcmcat240500050057 Action Camcorder Mounts
# │   ├── abcat0410000 Digital Camera Accessories
# │   │   ├── abcat0410018 Camera Lenses
# │   │   │   ├── pcmcat233000050008 DSLR Lenses
# │   │   │   │   └── pcmcat195200050001 Prime Lenses
# │   │   │   └── pcmcat374500050006 Mirrorless Lenses
# │   │   ├── abcat0410020 Filters & Accessories
# │   │   ├── abcat0410012 Camera Batteries & Power
# │   │   │   └── pcmcat284800050007 Camera Batteries
# │   │   ├── pcmcat240500050025 Flashes, Lighting & Studio
# │   │   │   └── pcmcat240500050052 Flashes & Accessories
# │   │   ├── pcmcat284800050006 Camera Bags, Cases & Straps
# │   │   │   └── abcat0410001 Camera Bags & Cases
# │   │   │       └── pcmcat328900050008 Universal Camera Bags & Cases
# │   │   └── abcat0410045 Tripods & Monopods
# │   ├── abcat0404000 Memory Cards
# │   │   └── pcmcat225800050009 All Memory Cards
# │   ├── abcat0409000 Binoculars, Telescopes & Optics
# │   │   └── abcat0409001 Binoculars
# │   └── abcat0410000 Camera & Camcorder Accessories
# ├── abcat0500000 Computers & Tablets
# │   ├── abcat0515000 Computer Accessories & Peripherals
# │   │   ├── abcat0515042 Surge Protectors & Power
# │   │   ├── pcmcat221100050003 Monitor & Screen Accessories
# │   │   ├── abcat0515025 Laptop Accessories
# │   │   │   ├── pcmcat183800050007 Laptop Chargers & Adapters
# │   │   │   ├── pcmcat183800050006 Laptop Batteries
# │   │   │   └── abcat0515028 Laptop Bags & Cases
# │   │   ├── abcat0513000 Mice & Keyboards
# │   │   │   ├── pcmcat338200050008 Mice
# │   │   │   └── abcat0513004 Computer Keyboards
# │   │   ├── abcat0504001 Hard Drives & Storage
# │   │   │   └── pcmcat186100050005 External Hard Drives
# │   │   ├── abcat0504010 USB Flash Drives
# │   │   └── abcat0515012 Cables & Connectors
# │   │       └── abcat0515013 USB Cables & Hubs
# │   ├── abcat0507000 Computer Cards & Components
# │   ├── pcmcat309900050001 iPad & Tablet Accessories
# │   │   └── pcmcat242000050002 Cases, Covers & Keyboard Folios
# │   │       └── pcmcat344400050007 Cases
# │   ├── abcat0509000 Monitors
# │   │   └── pcmcat200900050014 LED Monitors
# │   ├── abcat0508000 Software
# │   ├── pcmcat209000050006 Tablets
# │   │   └── pcmcat209000050008 All Tablets
# │   ├── abcat0503000 Networking & Wireless
# │   ├── abcat0502000 Laptops
# │   │   └── pcmcat138500050001 All Laptops
# │   │       └── pcmcat247400050000 PC Laptops
# │   ├── abcat0501000 Desktop & All-in-One Computers
# │   │   └── pcmcat143400050013 All Desktops
# │   └── pcmcat309900050001 iPad, Tablet & E-Reader Accessories
# ├── abcat0900000 Appliances
# │   ├── abcat0904000 Ranges, Cooktops & Ovens
# │   │   ├── abcat0904001 Cooktops
# │   │   ├── abcat0904004 Wall Ovens
# │   │   │   └── pcmcat180700050008 Single Ovens
# │   │   ├── abcat0904003 Ranges
# │   │   │   ├── pcmcat196400050015 Gas Ranges
# │   │   │   └── pcmcat196400050016 Electric Ranges
# │   │   └── abcat0904002 Range Hoods
# │   │       └── pcmcat207200050007 Wall Mount Range Hoods
# │   ├── abcat0912000 Small Kitchen Appliances
# │   │   ├── pcmcat367400050002 Coffee, Tea & Espresso
# │   │   │   ├── pcmcat367400050005 Coffee Pods & Beans
# │   │   │   │   └── abcat0912008 Coffee Pods
# │   │   │   ├── abcat0912005 Coffee Makers
# │   │   │   │   └── pcmcat258900050007 Multi-Cup Coffee Makers
# │   │   │   └── pcmcat367400050003 Tea Kettles
# │   │   │       └── pcmcat194000050023 Electric Tea Kettles
# │   │   ├── abcat0912011 Blenders & Juicers
# │   │   │   └── pcmcat194000050018 Blenders
# │   │   │       └── pcmcat258900050003 Full-Size Blenders
# │   │   ├── abcat0912014 Electric Griddles & Hotplates
# │   │   ├── abcat0912025 Kitchen Gadgets
# │   │   │   └── pcmcat251300050004 Food Preparation Utensils
# │   │   ├── abcat0912023 Toasters
# │   │   ├── abcat0912012 Slow Cookers, Crock Pots & Roaster Ovens
# │   │   ├── abcat0912020 Steamers, Rice Cookers & Pressure Cookers
# │   │   ├── pcmcat748301695371 Cookware, Bakeware & Cutlery
# │   │   │   ├── pcmcat226900050013 Cookware
# │   │   │   └── pcmcat748301695443 Bakeware
# │   │   ├── abcat0912018 Mixers & Mixer Accessories
# │   │   └── pcmcat194000050022 Specialty Appliances
# │   ├── abcat0902000 Freezers & Ice Makers
# │   ├── pcmcat302300050021 Heating, Cooling & Air Quality
# │   │   ├── abcat0907001 Air Conditioners
# │   │   ├── abcat0907007 Heaters
# │   │   ├── abcat0908003 Humidifiers
# │   │   ├── abcat0908001 Air Purifiers
# │   │   ├── pcmcat268100050002 Fireplaces
# │   │   └── abcat0907006 Fans
# │   ├── abcat0901000 Refrigerators
# │   │   └── pcmcat367400050001 All Refrigerators
# │   ├── abcat0903000 Microwaves
# │   │   └── pcmcat748301803023 All Microwaves
# │   ├── abcat0910000 Washers & Dryers
# │   │   ├── abcat0910004 Dryers
# │   │   │   ├── pcmcat232900050031 Electric Dryers
# │   │   │   └── pcmcat232900050030 Gas Dryers
# │   │   └── abcat0910001 Washing Machines
# │   ├── abcat0911000 Vacuum Cleaners & Floor Care
# │   ├── abcat0905000 Dishwashers
# │   │   └── abcat0905001 Built-In Dishwashers
# │   └── abcat0916000 Appliance Parts & Accessories
# │       ├── pcmcat303700050016 Air Purifier Filters & Parts
# │       └── abcat0916008 Vacuum & Floor Care Accessories
# ├── abcat0200000 Audio
# │   ├── abcat0204000 Headphones
# │   │   ├── pcmcat144700050004 All Headphones
# │   │   ├── pcmcat143000050011 Over-Ear & On-Ear Headphones
# │   │   │   ├── pcmcat331200050001 Over-Ear Headphones
# │   │   │   └── pcmcat331200050000 On-Ear Headphones
# │   │   └── pcmcat143000050007 Earbud & In-Ear Headphones
# │   ├── pcmcat241600050001 Home Audio
# │   │   ├── pcmcat309300050002 Receivers & Amplifiers
# │   │   ├── abcat0205000 Speakers
# │   │   │   ├── abcat0205006 Outdoor Speakers
# │   │   │   ├── pcmcat210900050000 In-Wall & In-Ceiling Speakers
# │   │   │   │   └── pcmcat210900050001 In-Ceiling Speakers
# │   │   │   └── abcat0205001 Bookshelf Speakers
# │   │   ├── abcat0203000 Home Theater Systems
# │   │   │   └── abcat0205007 Sound Bars
# │   │   └── pcmcat309300050003 CD Players & Turntables
# │   ├── abcat0208007 iPod & MP3 Player Accessories
# │   ├── pcmcat310200050004 Bluetooth & Wireless Speakers
# │   └── abcat0208000 Home Audio Accessories
# │       └── abcat0208015 Speaker Accessories
# ├── abcat0100000 TV & Home Theater
# │   ├── abcat0106000 TV Stands, Mounts & Furniture
# │   │   ├── pcmcat332100050008 Projector Mounts & Screens
# │   │   │   └── pcmcat158900050019 Projector Screens
# │   │   ├── abcat0106004 TV Mounts
# │   │   ├── abcat0106001 TV Stands
# │   │   │   └── pcmcat332100050000 All TV Stands
# │   │   └── abcat0106010 CD & DVD Media Storage
# │   ├── abcat0107000 TV & Home Theater Accessories
# │   │   └── abcat0107015 A/V Cables & Connectors
# │   ├── abcat0101000 TVs
# │   │   └── abcat0101001 All Flat-Panel TVs
# │   └── pcmcat158900050008 Projectors & Screens
# │       └── pcmcat158900050018 Projectors
# ├── pcmcat242800050021 Health, Fitness & Beauty
# │   ├── abcat0915000 Personal Care & Beauty
# │   │   ├── abcat0915009 Hair Care
# │   │   └── abcat0915005 Shavers & Trimmers
# │   ├── pcmcat352500050007 Health & Fitness Accessories
# │   ├── abcat0301006 Fitness & GPS Watches
# │   └── pcmcat210000050008 Activity Trackers & Pedometers
# ├── pcmcat128500050004 Name Brands
# ├── abcat0800000 Cell Phones
# │   ├── abcat0811002 Cell Phone Accessories
# │   │   ├── abcat0811006 Cell Phone Cases & Clips
# │   │   ├── pcmcat191200050015 iPhone Accessories
# │   │   │   └── pcmcat214700050000 iPhone Cases & Clips
# │   │   │       ├── pcmcat748300579994 iPhone 6s Plus Cases
# │   │   │       └── pcmcat748300580023 iPhone 6s Cases
# │   │   ├── abcat0811004 Cell Phone Batteries & Power
# │   │   │   ├── pcmcat326000050010 Portable Chargers/Power Packs
# │   │   │   └── pcmcat326000050011 Internal Batteries
# │   │   ├── pcmcat373300050003 Photography Accessories
# │   │   ├── abcat0811007 Adapters, Cables & Chargers
# │   │   │   ├── pcmcat171900050026 Wall Chargers & Power Adapters
# │   │   │   └── pcmcat171900050024 Car Chargers
# │   │   ├── pcmcat321000050003 Smartwatches & Accessories
# │   │   │   └── pcmcat321000050005 Smartwatch Accessories
# │   │   │       └── pcmcat350800050010 Smartwatch Bands
# │   │   └── pcmcat171900050031 Screen Protectors
# │   ├── pcmcat156400050037 Unlocked Cell Phones
# │   │   └── pcmcat311200050005 All Unlocked Cell Phones
# │   └── pcmcat209400050001 All Cell Phones with Plans
# ├── pcmcat139900050002 Magnolia Home Theater
# │   └── pcmcat748300660981 Magnolia Accessories
# │       └── pcmcat143200050025 Magnolia TV Stands, Mounts & Furniture
# ├── cat09000 Best Buy Gift Cards
# └── pcmcat332000050000 Wearable Technology
#     └── pcmcat748300489081 Apple Watch
#         └── pcmcat377500050002 Apple Watch Accessories
#             └── pcmcat377500050003 Apple Watch Bands & Straps

# %%
def dist_nodes(node_nm1, node_nm2, cat_tree_dict):
    """Takes two nodes names categories and the dictionary generated by maketree() function and returns the distance between them using anytree libray
    input: str names of nodes
    return: int distance between nodes """

    cat_node1 = cat_tree_dict[node_nm1]
    cat_node2 = cat_tree_dict[node_nm2]

    path_list1 = list(cat_node1.path)[1:]
    path_list2 = list(cat_node2.path)[1:]
    
    len_list_path = [len(path_list1), len(path_list2)]
    
    for lp in [path_list1, path_list2]:
      if len(lp) == max(len_list_path):
        max_length_list = lp
      else:
        min_length_list = lp
    
    dist = 1
    common_path = []
        

    for nd in max_length_list:
        if nd in min_length_list:
            common_path.append(nd)
            dist +=0
        else:
            dist += 1
    return dist # (dist, common_path)

# %% [markdown]
# ### Applying `make_tree()`function
#
# Finally, we made use of our `dist_nodes()` using categories present in our tree generated by the `make_tree()` function. This step complete the integration of our different functions

# %%
node1 = 'pcmcat179200050008 Patio Furniture & Decor'
node2 = 'pcmcat311200050005 All Unlocked Cell Phones'


print(dist_nodes(node1, node2, tree_dict))
dist_nodes(node1, node2, tree_dict) == dist_nodes(node2, node1, tree_dict)
# Out:
# 5
# True
