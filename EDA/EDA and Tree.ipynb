# %%
import pandas as pd
import numpy as np
import json
from anytree import Node, RenderTree

# %%
products = pd.read_json('https://raw.githubusercontent.com/anyoneai/e-commerce-open-data-set/master/products.json')
categories = pd.read_json('https://raw.githubusercontent.com/anyoneai/e-commerce-open-data-set/master/categories.json')

# %%
products[['name','description','category']].head(4)
# Out:
#                                               name  \
# 0                Duracell - AAA Batteries (4-Pack)
# 1  Duracell - AA 1.5V CopperTop Batteries (4-Pack)
# 2                 Duracell - AA Batteries (8-Pack)
# 3            Energizer - MAX Batteries AA (4-Pack)
#
#                                          description  \
# 0  Compatible with select electronic devices; AAA...
# 1  Long-lasting energy; DURALOCK Power Preserve t...
# 2  Compatible with select electronic devices; AA ...
# 3  4-pack AA alkaline batteries; battery tester i...
#
#                                             category
# 0  [{'id': 'pcmcat312300050015', 'name': 'Connect...
# 1  [{'id': 'pcmcat312300050015', 'name': 'Connect...
# 2  [{'id': 'pcmcat312300050015', 'name': 'Connect...
# 3  [{'id': 'pcmcat312300050015', 'name': 'Connect...

# %%
prod_cat = {} # new dictionary. 
for item in products.category: # each row of this column has a list of dictionaries.
    for dic in item: # each dictionary has a category 'id' with their respective 'name'.
        prod_cat[dic['id']] = dic['name'] # using 'id' and 'name' for new dict's keys and values.

# %%
# We now know all the categories present in the products table but we need to check the category
# table to identify root, parent and sibling relationships between them.
categories.head(4) # 'path' shows ancestors while 'subCategories' shows children of every node.
# Out:
#              id           name  \
# 0  abcat0010000     Gift Ideas
# 1  abcat0020001  Learning Toys
# 2  abcat0020002      DVD Games
# 3  abcat0020004   Unique Gifts
#
#                                                 path  \
# 0     [{'id': 'abcat0010000', 'name': 'Gift Ideas'}]
# 1  [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
# 2  [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
# 3  [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
#
#                                        subCategories
# 0  [{'id': 'pcmcat140000050035', 'name': 'Capturi...
# 1                                                 []
# 2                                                 []
# 3                                                 []

# %%
def levels(idx, path):
    root = path[0]['id']
    level = []
    if idx == root:
        level = 0
    else:
        level = len(path) - 1
    return level, root

levels = np.vectorize(levels)

# %%
categories['level'], categories['root'] = levels(categories.id,categories.path)

# %%
categories
# Out:
#                      id                                   name  \
# 0          abcat0010000                             Gift Ideas
# 1          abcat0020001                          Learning Toys
# 2          abcat0020002                              DVD Games
# 3          abcat0020004                           Unique Gifts
# 4          abcat0100000                      TV & Home Theater
# ...                 ...                                    ...
# 4579  pcmcat86300050019           New Sony Blu-ray Disc Player
# 4580  pcmcat86300050020          Movies Coming to Blu-ray Disc
# 4581  pcmcat86500050000  Blu-ray Disc and DVD-Video Comparison
# 4582  pcmcat87800050001                       Customer Service
# 4583  pcmcat94300050028                              Birthdays
#
#                                                    path  \
# 0        [{'id': 'abcat0010000', 'name': 'Gift Ideas'}]
# 1     [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
# 2     [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
# 3     [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
# 4     [{'id': 'abcat0100000', 'name': 'TV & Home The...
# ...                                                 ...
# 4579  [{'id': 'pcmcat128500050004', 'name': 'Name Br...
# 4580  [{'id': 'pcmcat128500050004', 'name': 'Name Br...
# 4581  [{'id': 'pcmcat128500050004', 'name': 'Name Br...
# 4582  [{'id': 'pcmcat87800050001', 'name': 'Customer...
# 4583  [{'id': 'abcat0010000', 'name': 'Gift Ideas'},...
#
#                                           subCategories  level  \
# 0     [{'id': 'pcmcat140000050035', 'name': 'Capturi...      0
# 1                                                    []      3
# 2                                                    []      3
# 3                                                    []      1
# 4     [{'id': 'abcat0101000', 'name': 'TVs'}, {'id':...      0
# ...                                                 ...    ...
# 4579  [{'id': 'pcmcat86300050020', 'name': 'Movies C...      3
# 4580                                                 []      4
# 4581                                                 []      4
# 4582     [{'id': 'pcmcat203400050001', 'name': 'Help'}]      0
# 4583                                                 []      1
#
#                     root
# 0           abcat0010000
# 1           abcat0010000
# 2           abcat0010000
# 3           abcat0010000
# 4           abcat0100000
# ...                  ...
# 4579  pcmcat128500050004
# 4580  pcmcat128500050004
# 4581  pcmcat128500050004
# 4582   pcmcat87800050001
# 4583        abcat0010000
#
# [4584 rows x 6 columns]
