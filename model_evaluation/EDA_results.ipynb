# %% [markdown]
# # EDA Prediction Results

# %%
import os
os.chdir("/home/app/src")
import pandas as pd
import numpy as np
import text_normalizer
from model import evaluation
from sklearn import metrics
from scripts.build_df import build_df
from scripts.decode_id import decode_id
from scripts.tree_utils import make_tree
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
df = build_df(json_path='data/products.json', threshold=100)

# %%
no_threshold_df = build_df(json_path='data/products.json', threshold=0)

# %%
def normalization(input):
    output = text_normalizer.normalize_corpus(
        input,
        html_stripping=True,
        contraction_expansion=True,
        accented_char_removal=True,
        text_lower_case=True,
        text_stemming=True,
        text_lemmatization=False,
        special_char_removal=True,
        remove_digits=False,
        stopword_removal=True,
        stopwords=text_normalizer.stopword_list
    )       
    return output

# %%
X = df['name'].copy()
X = normalization(X.apply(str))
y = df['leaf'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20, 
    random_state=42,
    stratify=y
)

# %%
tfid_vectorizer = TfidfVectorizer(max_features=1500, ngram_range=(1, 2)) 
X_train = tfid_vectorizer.fit_transform(X_train)
X_test = tfid_vectorizer.transform(X_test)

# %% [markdown]
# ### Hierarchical classification

# %%
# Initialize model
random_forest = RandomForestClassifier(n_jobs=-1)
random_forest.fit(X_train, y_train)

# Predict on train and test
y_pred_train = random_forest.predict(X_train)
y_pred_test = random_forest.predict(X_test)

# %%
tree = make_tree(df, df["category"], "root", display_tree=False)

# %%
evaluation.get_performance(random_forest, y_pred_test, np.array(y_test), tfid_vectorizer, "micro", tree)
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.815972894482091
# Precision: 0.815972894482091
# Recall: 0.815972894482091
# F1 Score: 0.815972894482091
# Average distance between nodes categories: 0.4089060987415295
#
# Model Classification report:
# ------------------------------
#                                            precision    recall  f1-score   support
#
#                       3D Printer Filament       0.94      1.00      0.97        47
#                   A/V Cables & Connectors       0.73      0.77      0.75        90
#                   Action Camcorder Mounts       0.50      0.71      0.59        28
#            Activity Trackers & Pedometers       0.82      0.82      0.82        39
#               Adapters, Cables & Chargers       0.75      0.75      0.75        71
#                          Air Conditioners       0.96      0.93      0.95        28
#              Air Purifier Filters & Parts       1.00      0.81      0.89        21
#                             Air Purifiers       0.91      0.88      0.89        24
#                All Cell Phones with Plans       0.93      0.82      0.87        33
#                              All Desktops       0.94      0.93      0.94        88
#                        All Flat-Panel TVs       0.92      0.77      0.84        31
#                            All Headphones       0.31      0.15      0.21        26
#                               All Laptops       0.85      0.88      0.87        33
#                          All Memory Cards       0.78      0.82      0.80        22
#                            All Microwaves       1.00      0.97      0.98        59
#                 All Point & Shoot Cameras       0.73      0.92      0.81        24
#                              All Printers       0.98      0.98      0.98        49
#                         All Refrigerators       0.77      0.82      0.80       138
#                             All TV Stands       0.81      0.96      0.88        82
#                               All Tablets       0.86      0.91      0.88        46
#                  All Unlocked Cell Phones       0.98      1.00      0.99        61
#                       Antennas & Adapters       1.00      0.86      0.92        21
#                Apple Watch Bands & Straps       0.92      0.92      0.92        26
#             Appliance Parts & Accessories       0.82      0.76      0.79        62
#                                Appliances       0.80      0.80      0.80        20
#                                     Audio       0.68      0.83      0.75        23
#                                  Bakeware       0.91      0.81      0.85        36
#                       Best Buy Gift Cards       0.97      0.97      0.97        91
#                                Binoculars       1.00      0.97      0.99        37
#           Binoculars, Telescopes & Optics       0.91      0.97      0.94        40
#                                  Blenders       0.70      0.64      0.67        25
#             Bluetooth & Wireless Speakers       0.85      0.92      0.89       142
#                        Bookshelf Speakers       0.89      0.71      0.79        24
#                      Built-In Dishwashers       1.00      1.00      1.00        53
#                    CD & DVD Media Storage       0.74      0.92      0.82        25
#                   CD Players & Turntables       0.68      0.81      0.74        21
#                     Camcorder Accessories       0.63      0.49      0.55        35
#               Camera Bags, Cases & Straps       0.58      0.70      0.63        27
#                          Camera Batteries       0.73      0.91      0.81        44
#                  Camera Batteries & Power       0.87      0.52      0.65        25
#                            Car Amplifiers       0.82      0.96      0.88        24
#              Car Audio Installation Parts       0.80      0.67      0.73        52
#                              Car Chargers       0.71      0.75      0.73        20
#                     Car Electronics & GPS       0.75      0.63      0.68        43
#      Car Installation Parts & Accessories       0.88      0.54      0.67        28
#                              Car Speakers       0.87      0.96      0.92        28
#                      Car Stereo Receivers       0.92      1.00      0.96        24
#                            Car Subwoofers       0.77      0.87      0.82        23
#                                     Cases       0.87      0.87      0.87        53
#           Cases, Covers & Keyboard Folios       0.82      0.89      0.85       112
#                    Cell Phone Accessories       0.69      0.61      0.65        57
#              Cell Phone Batteries & Power       0.62      0.57      0.60        44
#                  Cell Phone Cases & Clips       0.91      0.93      0.92       370
#                               Cell Phones       0.88      0.82      0.85        51
#                             Coffee Makers       0.60      0.60      0.60        20
#                               Coffee Pods       1.00      0.95      0.98        21
#                    Coffee, Tea & Espresso       0.75      0.65      0.70        46
#        Computer Accessories & Peripherals       0.77      0.54      0.63        37
#               Computer Cards & Components       0.62      0.77      0.69        71
#                        Computer Keyboards       0.85      1.00      0.92        23
#                            Connected Home       0.74      0.79      0.77        58
#               Connected Home & Housewares       0.73      0.69      0.71        32
#                                  Cooktops       0.98      0.98      0.98        51
#                                  Cookware       0.84      0.89      0.86        97
#                   DJ & Lighting Equipment       0.57      0.64      0.60        33
#                               DSLR Lenses       0.71      0.86      0.78        35
#                    Dash Installation Kits       0.93      0.96      0.94       148
#                            Deck Harnesses       0.89      0.91      0.90        34
#                                     Desks       0.73      0.80      0.76        30
#                Digital Camera Accessories       0.70      0.58      0.63        66
#                           Digital Cameras       0.90      0.97      0.93        36
#                      Drones & Accessories       0.77      0.55      0.64        31
#                        Drums & Percussion       0.74      0.85      0.79        33
#                Earbud & In-Ear Headphones       0.90      0.91      0.91        80
#                           Electric Dryers       1.00      1.00      1.00        26
#             Electric Griddles & Hotplates       0.65      0.52      0.58        21
#                           Electric Ranges       0.95      1.00      0.98        61
#                      Electric Tea Kettles       0.70      0.83      0.76        23
#                      External Hard Drives       0.78      0.88      0.82        24
#                                      Fans       0.91      1.00      0.95        49
#                     Filters & Accessories       0.91      0.97      0.94        64
#                                Fireplaces       0.77      0.77      0.77        31
#                     Fitness & GPS Watches       0.90      0.95      0.92        39
#                     Flashes & Accessories       0.77      0.74      0.75        27
#                 Food Preparation Utensils       0.66      0.58      0.62        69
#                     Freezers & Ice Makers       0.83      0.89      0.86        27
#                        Full-Size Blenders       0.65      0.87      0.74        23
#                         Furniture & Decor       0.68      0.52      0.59        25
#              GPS Navigation & Accessories       0.93      0.74      0.83        35
#                 Game Room & Bar Furniture       0.91      0.91      0.91        34
#                                Gas Dryers       1.00      1.00      1.00        23
#                                Gas Ranges       1.00      1.00      1.00        57
#                                    Grills       0.79      0.84      0.81        31
#                        Guitar Accessories       0.87      0.68      0.76        38
#                                 Hair Care       0.78      0.74      0.76        34
#                     Hard Drives & Storage       0.86      0.84      0.85        38
#                                Headphones       0.57      0.63      0.60        38
#              Health & Fitness Accessories       0.89      0.94      0.92        36
#                  Health, Fitness & Beauty       0.90      0.50      0.64        36
#                                   Heaters       0.94      1.00      0.97        33
#                                Home Audio       0.39      0.36      0.37        25
#                       Household Batteries       0.83      0.97      0.90        36
#                               Humidifiers       0.96      0.96      0.96        28
#                       In-Ceiling Speakers       0.86      0.90      0.88        21
#             In-Wall & In-Ceiling Speakers       0.84      0.80      0.82        20
#            Instrument Instructional Books       0.62      0.54      0.58        24
#                        Internal Batteries       0.85      0.74      0.80        47
#                                 Keyboards       0.78      0.90      0.84        20
#                           Kitchen Gadgets       0.72      0.67      0.70        43
#                              LED Monitors       0.76      0.85      0.80        33
#                       Laptop Bags & Cases       0.84      0.92      0.88        87
#                          Laptop Batteries       1.00      0.94      0.97        52
#                Laptop Chargers & Adapters       0.70      0.70      0.70        23
#                      Learning & Education       0.61      0.81      0.69        21
#                     Living Room Furniture       0.75      0.83      0.79        29
#                                   Luggage       0.87      0.84      0.85        31
#    Magnolia TV Stands, Mounts & Furniture       0.91      0.84      0.87        25
#                      Marine & Powersports       0.84      0.64      0.72        33
#                                      Mice       0.87      1.00      0.93        27
#                               Microphones       0.62      0.89      0.73        36
#                 Microphones & Accessories       0.50      0.55      0.52        20
#                  Microphones & Live Sound       0.42      0.44      0.43        34
#                         Mirrorless Lenses       0.52      0.60      0.56        20
#                Mixers & Mixer Accessories       0.88      0.95      0.91        39
#              Monitor & Screen Accessories       0.85      0.55      0.67        20
#                                  Monitors       0.71      0.62      0.67        24
#                   Multi-Cup Coffee Makers       0.81      0.63      0.71        27
#            Musical Instrument Accessories       0.60      0.48      0.53        65
#                       Musical Instruments       0.88      0.60      0.71        70
#                               Name Brands       0.68      0.58      0.63        43
#                     Networking & Wireless       0.86      0.93      0.90        46
#                              Nintendo 3DS       0.92      0.92      0.92        24
#                         Nintendo DS Games       0.89      0.97      0.93        34
#                             Office Chairs       0.97      0.97      0.97        37
#                        Office Electronics       0.71      0.73      0.72        33
#                Office Furniture & Storage       0.66      0.66      0.66        29
#                         On-Ear Headphones       0.78      0.91      0.84        35
#                           Outdoor Heating       0.86      0.86      0.86        21
#                           Outdoor Seating       0.85      0.92      0.88        24
#                          Outdoor Speakers       0.77      0.87      0.82        31
#                       Over-Ear Headphones       0.74      0.82      0.78        39
#                                 PC Gaming       0.41      0.29      0.34        24
#                                PC Laptops       0.96      0.97      0.96        69
#                                 PS3 Games       0.56      0.27      0.36        37
#                                 PS4 Games       0.57      0.86      0.69        51
#                   Patio Furniture & Decor       0.75      0.85      0.80        48
#                                    Pedals       0.72      0.62      0.67        21
#                    Personal Care & Beauty       0.79      0.66      0.72        41
#                   Photography Accessories       0.90      0.78      0.84        23
#                     Point & Shoot Cameras       1.00      0.25      0.40        20
#             Portable Chargers/Power Packs       0.84      0.90      0.87        69
#                           Pre-Owned Games       0.99      1.00      1.00       711
#                              Prime Lenses       0.68      0.71      0.70        21
#                               Printer Ink       0.92      0.96      0.94       100
#                         Projector Screens       1.00      1.00      1.00        23
#                                Projectors       1.00      1.00      1.00        28
#                    Receivers & Amplifiers       0.82      0.79      0.81        34
#                       Recording Equipment       0.55      0.42      0.47        55
#                             Refrigerators       0.62      0.50      0.55        56
#                         Screen Protectors       0.96      0.88      0.92        25
#                   Security Camera Systems       0.92      0.92      0.92        24
#           Security Cameras & Surveillance       0.88      0.79      0.84        29
#                        Shavers & Trimmers       0.63      0.41      0.50        29
#                               Sheet Music       0.84      0.92      0.88       124
#                        Sheet Music & DVDs       0.57      0.40      0.47        20
#                              Single Ovens       0.92      1.00      0.96        22
#  Slow Cookers, Crock Pots & Roaster Ovens       0.88      0.77      0.82        30
#                  Small Kitchen Appliances       0.64      0.64      0.64        73
#                          Smartwatch Bands       0.98      0.98      0.98        47
#                                  Software       0.75      0.87      0.81        77
#                                Sound Bars       1.00      0.87      0.93        23
#                       Speaker Accessories       0.71      0.69      0.70        36
#                                  Speakers       0.82      0.77      0.80        61
#                      Specialty Appliances       0.77      0.66      0.71        61
# Steamers, Rice Cookers & Pressure Cookers       0.85      0.71      0.77        24
#                  Surge Protectors & Power       0.80      0.74      0.77        27
#                                   Systems       0.75      1.00      0.86        21
#                         TV & Home Theater       0.83      0.65      0.73        23
#             TV & Home Theater Accessories       0.72      0.77      0.74        43
#                                 TV Mounts       0.91      0.87      0.89        45
#                TV, Movie & Character Toys       0.73      0.59      0.65        27
#                                       TVs       0.73      0.86      0.79        22
#                                   Tablets       0.85      0.81      0.83        21
#                     Telephone Accessories       0.77      0.77      0.77        22
#                Telephones & Communication       0.71      0.63      0.67        27
#                                  Toasters       0.93      0.97      0.95        29
#                                     Toner       0.85      0.90      0.87        67
#                              Toys to Life       0.91      1.00      0.95        49
#                      Toys, Games & Drones       0.59      0.65      0.62        55
#                        Tripods & Monopods       0.63      0.53      0.58        36
#                         USB Cables & Hubs       0.64      0.78      0.71        23
#                          USB Flash Drives       1.00      0.98      0.99        64
#             Universal Camera Bags & Cases       0.71      0.76      0.74        33
#           Vacuum & Floor Care Accessories       0.70      0.74      0.72        38
#              Vacuum Cleaners & Floor Care       0.87      0.90      0.89        69
#                    Video Game Accessories       0.36      0.23      0.28        22
#                               Video Games       0.73      0.38      0.50        58
#                                  Wall Art       1.00      1.00      1.00        25
#            Wall Chargers & Power Adapters       0.72      0.82      0.77        22
#                    Wall Mount Range Hoods       0.88      1.00      0.93        42
#                                Wall Ovens       1.00      0.91      0.95        23
#                          Washing Machines       1.00      1.00      1.00        27
#                                       Wii       0.58      0.83      0.68        23
#                            Xbox 360 Games       0.88      0.90      0.89        41
#                                  Xbox One       0.90      0.95      0.93        20
#                            Xbox One Games       0.98      1.00      0.99        43
#                 iPad & Tablet Accessories       0.82      0.68      0.75        60
#                           iPhone 6s Cases       0.80      0.74      0.77        43
#                      iPhone 6s Plus Cases       0.73      0.76      0.75        25
#                        iPhone Accessories       0.65      0.46      0.54        37
#                      iPhone Cases & Clips       0.87      0.95      0.90       311
#             iPod & MP3 Player Accessories       0.52      0.38      0.44        29
#                                     other       0.61      0.64      0.62       556
#
#                                  accuracy                           0.82     10330
#                                 macro avg       0.80      0.79      0.79     10330
#                              weighted avg       0.82      0.82      0.81     10330

# %%
results = pd.read_csv("model/experiments/exp2022-12-14 11:09:07.414935/results.csv")
results.rename(columns={"Unnamed: 0":"leaf"}, inplace=True)
# Drop compound columns
results = results[:-3]
results["leaf"] = results["leaf"].apply(lambda x: decode_id(x))

# %%
results.sort_values(by="support", ascending=False).head(40)
# Out:
#                                 leaf  precision    recall  f1-score  support
# 148                  Pre-Owned Games   0.994406  1.000000  0.997195    711.0
# 92                             other   0.608247  0.636691  0.622144    556.0
# 61          Cell Phone Cases & Clips   0.912234  0.927027  0.919571    370.0
# 142             iPhone Cases & Clips   0.867257  0.945338  0.904615    311.0
# 114           Dash Installation Kits   0.928105  0.959459  0.943522    148.0
# 185    Bluetooth & Wireless Speakers   0.850649  0.922535  0.885135    142.0
# 202                All Refrigerators   0.773973  0.818841  0.795775    138.0
# 134                      Sheet Music   0.838235  0.919355  0.876923    124.0
# 155  Cases, Covers & Keyboard Folios   0.819672  0.892857  0.854701    112.0
# 54                       Printer Ink   0.923077  0.960000  0.941176    100.0
# 146                         Cookware   0.843137  0.886598  0.864322     97.0
# 91               Best Buy Gift Cards   0.967033  0.967033  0.967033     91.0
# 6            A/V Cables & Connectors   0.734043  0.766667  0.750000     90.0
# 97                      All Desktops   0.942529  0.931818  0.937143     88.0
# 42               Laptop Bags & Cases   0.842105  0.919540  0.879121     87.0
# 195                    All TV Stands   0.814433  0.963415  0.882682     82.0
# 95        Earbud & In-Ear Headphones   0.901235  0.912500  0.906832     80.0
# 37                          Software   0.752809  0.870130  0.807229     77.0
# 77          Small Kitchen Appliances   0.643836  0.643836  0.643836     73.0
# 36       Computer Cards & Components   0.625000  0.774648  0.691824     71.0
# 62       Adapters, Cables & Chargers   0.746479  0.746479  0.746479     71.0
# 13               Musical Instruments   0.875000  0.600000  0.711864     70.0
# 161        Food Preparation Utensils   0.655738  0.579710  0.615385     69.0
# 158                       PC Laptops   0.957143  0.971014  0.964029     69.0
# 76      Vacuum Cleaners & Floor Care   0.873239  0.898551  0.885714     69.0
# 189    Portable Chargers/Power Packs   0.837838  0.898551  0.867133     69.0
# 55                             Toner   0.845070  0.895522  0.869565     67.0
# 28        Digital Camera Accessories   0.703704  0.575758  0.633333     66.0
# 16    Musical Instrument Accessories   0.596154  0.476923  0.529915     65.0
# 30             Filters & Accessories   0.911765  0.968750  0.939394     64.0
# 35                  USB Flash Drives   1.000000  0.984375  0.992126     64.0
# 89     Appliance Parts & Accessories   0.824561  0.758065  0.789916     62.0
# 9                           Speakers   0.824561  0.770492  0.796610     61.0
# 186         All Unlocked Cell Phones   0.983871  1.000000  0.991870     61.0
# 128             Specialty Appliances   0.769231  0.655738  0.707965     61.0
# 132                  Electric Ranges   0.953125  1.000000  0.976000     61.0
# 184        iPad & Tablet Accessories   0.820000  0.683333  0.745455     60.0
# 212                   All Microwaves   1.000000  0.966102  0.982759     59.0
# 44                       Video Games   0.733333  0.379310  0.500000     58.0
# 165                   Connected Home   0.741935  0.793103  0.766667     58.0
